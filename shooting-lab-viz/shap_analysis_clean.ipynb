# %% [markdown]
# # SHAP-Guided Shooting Biomechanics — Capstone 2025-2026
#
# The pipeline is a three-stage causal chain:
#
# ```
# Biomechanics  ──Stage 1──►  Ball Flight  ──Stage 2──►  Miss Distance
#                                                   ↑
#                              Stage 3 (direct, R²≈0 — device limitation, explained in §7)
# ```
#
# For each shot a user selects in the Unity viewer, the system shows:
# - The player's **original pose** (`orig_*` joint angles) and the **recommended pose** (`rec_*`)
# - **3–4 joint-angle changes** chosen by per-shot SHAP — the features most actively pushing that shot's predicted ball flight outside the made-shot optimal band
# - **Predicted ball-flight improvement** (`orig_pred_*` → `rec_pred_*`) for release height, launch angle, velocity, and arc
#
# ---
#
# ## Running the notebook
#
# Sections **8 (Player analysis)** and **11 (Unity export)** default to single-player mode (`PLAYER_ID = 'Player 163'`). A loop-control cell before Section 9 sets `RUN_ALL_PLAYERS = False`. Set it to `True` and run the optional batch cell after Section 11 to process all 165 players.
#
# ---
#
# ## What changed vs `phillip/shap_model`
#
# **Methodology**
# - `GroupKFold(groups=PlayerID)` for all CV R² — random folds leaked Player 163's 13% data share into every split, inflating held-out scores.
# - Sentinel cleanup: 8 alignment columns had `-1e9` markers blowing std into the millions.
# - Circular std (`scipy.stats.circstd`) for `*Alignment*` features — linear std mishandles ±180° wrap.
# - Per-player sample cap (500 shots) so no single player dominates the loss.
#
# **Stage 3 redesign**
# - Switched the direct outcome from `Made` (binary, AUC) to `Ball.Distance.from.Center` (continuous, R²). More information per shot.
# - Added a free-throw parallel pipeline as a clean-conditions sanity check — FT R²_cv ≈ 0 confirms the device misses release-point dynamics regardless of shot context.
#
# **Feature engineering**
# - Within-player z-scores (`__zwithin`) for the consistency signal.
# - Dom/NonDom symmetry diffs.
# - Year + DaysSinceFirstShot.
# - Unlocked release-point biomech features (`BallXRelease`, etc.) previously dropped by an over-broad substring filter.
# - Height-normalized release height replaces raw `Release.Height` to remove the stature confound.
#
# **Recommendation engine (replaces DiCE counterfactuals)**
# - Per-shot SHAP from Stage 1 (biomech → ball flight) scores each joint-angle feature by how strongly it is *hurting* that shot's predicted ball flight.
# - **Strict Context Filtering:** The ML models must incorporate situational context (`Shot.Distance`, `Shot.Type`, `Year`, `Days`) so they don't incorrectly attribute higher miss rates from deep distances to a player's biomechanics. However, when we rank the top features to *fix* in our SHAP recommendations, we aggressively filter out these uncoachable context attributes. We only serve actual actionable, biomechanical changes to the coach.
# - Top 3–4 features are changed to the **player's own makes-median** — the animation shows what *his* form looks like on successful shots, not a population average.
# - **Biomechanical Guardrails:** Recommended changes are capped at a maximum functional delta (e.g. ±12° or scaled bounds) to ensure realism in Unity generation and prevent impossible biomechanical poses.
# - Recommended feature vectors are re-predicted through Stage 1 to produce `rec_pred_*` ball-flight columns.
# - Optimal band defined as 40–60th percentile of **made shots only** (entry angle, arc, velocity have optima, not maxima — higher is not always better).
#
#
#
# **Output**
# - Per-shot Unity-ready CSV: `orig_*` / `rec_*` joint-angle pose pairs (Flexion, Extension, Alignment, ROM, Velocity columns across all shot phases) plus `orig_pred_*` / `rec_pred_*` ball-flight predictions per Stage 1 target.
#
# ---
#
# ## Sections
# 1. Setup & data loading
# 2. Preprocessing (handedness normalization, sentinel cleanup, shot-type filter)
# 3. Feature engineering (zwithin, symmetry diffs, context features)
# 4. Stage 1 models — biomech → ball flight (LightGBM, GroupKFold CV)
# 5. Global SHAP — cross-target feature importance heatmap
# 6. Stage 2 — ball flight → miss distance (Random Forest per shot context)
# 7. Stage 3 sanity check — direct biomech → BDFC (confirms device limitation)
# 8. Player analysis — ball-flight scorecard, make/miss self-comparison, consistency vs peers
# 9. Counterfactual recommendations — DiCE (skipped when no ball-flight gap fires)
# 10. Free-throw sanity check
# 11. Unity export — per-shot SHAP-guided biomechanical recommendations
# 12. Summary

# %% [markdown]
# ## 1. Setup

# %%
# %pip install -q "numpy<2" shap dice-ml lightgbm
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.32.0 requires protobuf<5,>=3.20, but you have protobuf 5.29.3 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, re, joblib, warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import shap
import dice_ml
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, GroupKFold
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import RobustScaler
from scipy.stats import circstd, spearmanr

warnings.filterwarnings('ignore')
shap.initjs()
plt.rcParams['figure.dpi'] = 110
sns.set_style('whitegrid')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %%
CSV_CANDIDATES = [
    'capstone2026v2.csv',
    '../capstone2026v2.csv',
    '/Users/shahil/Documents/UCSB/2025-2026/P3/capstone2026v2.csv',
]
DATA_PATH = next((p for p in CSV_CANDIDATES if os.path.exists(p)), None)
if DATA_PATH is None:
    raise FileNotFoundError('capstone2026v2.csv not found in any expected location.')

df_raw = pd.read_csv(DATA_PATH).rename(columns={'Name': 'PlayerID'})
print(f'Loaded {len(df_raw):,} shots × {df_raw.shape[1]} cols  |  '
      f'{df_raw.PlayerID.nunique()} players  |  '
      f'{df_raw.Date.min()} → {df_raw.Date.max()}')
# Out:
# Loaded 25,868 shots × 264 cols  |  165 players  |  1/18/2025 14:17 → 9/9/2024 9:18

# %% [markdown]
# ## 2. Preprocessing
#
# Three things happen here: handedness normalization (so all biomech features refer to the dominant side), sentinel-value cleanup, and the jump-shot filter.
#
# The handedness logic reflects left-handed players into a right-handed reference frame and renames Left/Right columns to NonDominant/Dominant. After this step, "Dominant" always means the shooting hand.

# %%
def _reflect_across_shot_axis(x, y):
    n = np.sqrt(x**2 + y**2)
    if n == 0:
        return x, y
    ux, uy = x / n, y / n
    px, py = (x*ux + y*uy) * ux, (x*ux + y*uy) * uy
    return x - 2*(x - px), y - 2*(y - py)


def standardize_handedness(df):
    df = df.copy()
    left = df['hand'] == 'Left'

    coords = df.loc[left, ['Shot.X.Pos', 'Shot.Y.Pos']].values
    if len(coords) > 0:
        ref = np.array([_reflect_across_shot_axis(x, y) for x, y in coords])
        df.loc[left, 'Shot.X.Pos'] = ref[:, 0]
        df.loc[left, 'Shot.Y.Pos'] = ref[:, 1]
    df.loc[left, 'Shot.X.Pos'] *= -1

    x_cols = [c for c in df.columns if re.search(r'(^|_)X($|[A-Z])', c)]
    y_cols = [c for c in df.columns if re.search(r'(^|_)Y($|[A-Z])', c)]
    for x_col, y_col in zip(x_cols, y_cols):
        coords = df.loc[left, [x_col, y_col]].values
        if len(coords) > 0:
            ref = np.array([_reflect_across_shot_axis(x, y) for x, y in coords])
            df.loc[left, x_col] = ref[:, 0]
            df.loc[left, y_col] = ref[:, 1]
        df.loc[left, x_col] *= -1

    for left_col in [c for c in df.columns if 'Left' in c]:
        right_col = left_col.replace('Left', 'Right')
        if right_col in df.columns:
            tmp = df.loc[left, left_col].copy()
            df.loc[left, left_col] = df.loc[left, right_col]
            df.loc[left, right_col] = tmp

    rename = {c: c.replace('Right', 'Dominant') for c in df.columns if 'Right' in c}
    rename.update({c: c.replace('Left', 'NonDominant') for c in df.columns if 'Left' in c})
    return df.rename(columns=rename)

# %%
SHOT_GROUP = 'JumpShots'   # 'JumpShots' | 'FreeThrow' | 'All'

df = standardize_handedness(df_raw)

# Sentinel cleanup -- 8 alignment cols had -1e9 markers (10 rows total).
num_cols = df.select_dtypes('number').columns
n_sentinels = int((df[num_cols].abs() > 1e6).sum().sum())
df[num_cols] = df[num_cols].mask(df[num_cols].abs() > 1e6)
print(f'Cleaned {n_sentinels} sentinel cells (|x| > 1e6 → NaN)')

# Free throws are mechanically distinct -- model them separately.
if SHOT_GROUP == 'JumpShots':
    df = df[df['Shot.Location'] != 'Free Throw'].copy()
elif SHOT_GROUP == 'FreeThrow':
    df = df[df['Shot.Location'] == 'Free Throw'].copy()

# Height-normalized release: drops the "tall players release high" trivial signal
if {'Release.Height', 'ht'}.issubset(df.columns):
    df['Release.Height.Norm'] = df['Release.Height'] / df['ht']

# Temporal features
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Year'] = df['Date'].dt.year
df['DaysSinceFirstShot'] = (df['Date'] - df.groupby('PlayerID')['Date'].transform('min')).dt.days

print(f'{SHOT_GROUP}: {len(df):,} shots × {df.PlayerID.nunique()} players')
# Out:
# Cleaned 10 sentinel cells (|x| > 1e6 → NaN)
# JumpShots: 21,901 shots × 165 players

# %% [markdown]
# ## 3. Feature engineering
#
# `X_full` has four feature families. Only `BIOMECH_FEATURES` is exposed to DiCE for counterfactual generation — those are the ones a coach can actually act on. The others help the model condition properly.
#
# | Family | What it captures |
# |---|---|
# | `BIOMECH_FEATURES` | Raw joint angles, ROMs, velocities |
# | `__zwithin` | Per-player z-scores — within-player consistency signal |
# | `DomDiff` | Dom − NonDom asymmetry |
# | Context | Shot.Distance, shot type one-hots, Year |

# %%
BIO_KEYWORDS = ['ankle','knee','hip','shoulder','elbow','torso','wrist',
                'flexion','extension','alignment','rom','velocity','velo',
                'dorsiflexion','plantarflexion','stance','gap']
EXCLUDE_KEYWORDS = ['time','made','shot.location','shot.type','shot.x','shot.y',
                    'pos.x','pos.y','pos.z','distance.from','date','name','playerid','hand']
KNOWN_TARGETS = {
    'Ball_to_Rim_Angle','Ball_Velocity','Release.Height','Release.Height.Norm',
    'Initial.Ball.Angle','Initial.Ball.Velocity','Max.Ball.Arc',
    'Made','Ball.Distance.from.Center','Shot.X.Pos','Shot.Y.Pos',
}


# ── Circular-angle utilities ────────────────────────────────────────────────
# Only Hip/Shoulder/Feet alignment columns are truly circular (range [-180, 180]
# with wrap). Flexion / ROM / velocity are bounded linear -- no wrap.
def is_circular(name):
    return 'alignment' in name.lower()


def circular_diff(a, b, period=360, half=180):
    """Shortest-arc a - b, returned in [-half, half]. Vectorized."""
    return ((np.asarray(a) - np.asarray(b) + half) % period) - half


def circular_mean(values, period=360, half=180):
    """Mean angle in [-half, half]. Returns NaN if empty."""
    arr = np.asarray(pd.Series(values).dropna(), dtype=float)
    if len(arr) == 0:
        return float('nan')
    rad = np.deg2rad(arr)
    return float(np.rad2deg(np.arctan2(np.sin(rad).mean(), np.cos(rad).mean())))


def select_biomech(df):
    """Pick biomechanical feature columns by token match (so 'x' won't match 'flexion')."""
    out = []
    for c in df.columns:
        if c in KNOWN_TARGETS:
            continue
        cl = c.lower()
        tokens = set(re.split(r'[._\- ]+', cl))
        if tokens & set(EXCLUDE_KEYWORDS):
            continue
        if any(k in cl for k in BIO_KEYWORDS):
            out.append(c)
    return out


def add_within_player(df, cols, group='PlayerID'):
    """Adds <col>__zwithin = z-score within each player.

    Linear (mean, std) for bounded features. For circular alignment columns:
    centers via circular_mean and scales by circstd, with circular subtraction
    so a shot at +175 vs player-mean -175 gets z ≈ 0 (10° arc), not z = huge.
    """
    out = df.copy()
    for c in cols:
        if c not in df.columns:
            continue
        if is_circular(c):
            cm = df.groupby(group)[c].transform(
                lambda g: circular_mean(g) if g.notna().any() else np.nan
            )
            cs = df.groupby(group)[c].transform(
                lambda g: float(circstd(g.dropna().values, high=180, low=-180))
                          if g.notna().sum() > 1 else np.nan
            ).replace(0, np.nan)
            d = circular_diff(df[c].values, cm.values)
            out[f'{c}__zwithin'] = pd.Series(d, index=df.index).div(cs).fillna(0)
        else:
            m = df.groupby(group)[c].transform('mean')
            s = df.groupby(group)[c].transform('std').replace(0, np.nan)
            out[f'{c}__zwithin'] = ((df[c] - m) / s).fillna(0)
    return out


def add_symmetry(df):
    """Dom - NonDom diff for each paired column. (Ratios were tested and add no held-out signal.)"""
    out = df.copy()
    new = []
    for c in df.columns:
        if 'NonDominant' in c or 'Dominant' not in c:
            continue
        partner = c.replace('Dominant', 'NonDominant')
        if partner in df.columns:
            diff = c.replace('Dominant', 'DomDiff')
            # Alignment columns aren't paired Dom/NonDom (they're whole-segment),
            # so circular handling isn't needed here in practice.
            out[diff] = df[c] - df[partner]
            new.append(diff)
    return out, new

# %%
BIOMECH_FEATURES = list(df[select_biomech(df)].select_dtypes('number').columns)

df = add_within_player(df, BIOMECH_FEATURES)
ZWITHIN_FEATURES = [f'{c}__zwithin' for c in BIOMECH_FEATURES if f'{c}__zwithin' in df.columns]

df, SYMMETRY_FEATURES = add_symmetry(df)

ctx_pieces, ctx_names = [], []
if 'Shot.Distance' in df.columns:
    ctx_pieces.append(df[['Shot.Distance']]); ctx_names.append('Shot.Distance')
if 'Shot.Type' in df.columns:
    st = pd.get_dummies(df['Shot.Type'], prefix='ShotType', dtype=int)
    ctx_pieces.append(st); ctx_names += st.columns.tolist()
if 'Year' in df.columns:
    ctx_pieces.append(df[['Year', 'DaysSinceFirstShot']])
    ctx_names += ['Year', 'DaysSinceFirstShot']
CONTEXT_FEATURES = ctx_names

X_full = pd.concat([df[BIOMECH_FEATURES], df[ZWITHIN_FEATURES],
                    df[SYMMETRY_FEATURES] if SYMMETRY_FEATURES else None,
                    *ctx_pieces], axis=1)
X_full = X_full.loc[:, ~X_full.columns.duplicated()]

print(f'X_full = {X_full.shape[1]} cols  '
      f'(biomech {len(BIOMECH_FEATURES)} + zwithin {len(ZWITHIN_FEATURES)} + '
      f'symmetry {len(SYMMETRY_FEATURES)} + context {len(CONTEXT_FEATURES)})')

counts = df.PlayerID.value_counts()
print(f'Shots/player: median {counts.median():.0f}  max {counts.max()}  '
      f'(top: {counts.index[0]}, {counts.iloc[0]/len(df):.1%} of dataset)')
# Out:
# X_full = 546 cols  (biomech 206 + zwithin 206 + symmetry 130 + context 5)
# Shots/player: median 76  max 2873  (top: Player 163, 13.1% of dataset)

# %% [markdown]
# ## 4. Stage 1 — Biomechanics → Ball Flight
#
# LightGBM regressor per ball-flight target. Held-out R² uses `GroupKFold(groups=PlayerID)` so a player never appears in both train and test. We also cap any single player at 500 shots before fitting — Player 163 alone has 13% of the data, and without the cap the model would essentially be predicting his shots.
#
# `R2_MIN_FOR_DICE = 0.20` is the gate for downstream counterfactual generation. Below that, recommendations would be noise.

# %%
BALL_FLIGHT_TARGETS = [
    'Release.Height.Norm', 'Initial.Ball.Angle',
    'Initial.Ball.Velocity', 'Max.Ball.Arc',
]
R2_MIN_FOR_DICE = 0.20
PER_PLAYER_CAP = 500
MODEL_DIR = 'saved_models'
os.makedirs(MODEL_DIR, exist_ok=True)


def cap_per_player(X, y, groups, cap=PER_PLAYER_CAP, seed=42):
    if cap is None:
        return X, y, groups
    rng = np.random.default_rng(seed)
    g = pd.Series(groups, index=X.index)
    keep = pd.Series(True, index=X.index)
    for player, n in g.value_counts().items():
        if n > cap:
            idx = X.index[g == player]
            drop = rng.choice(idx.values, size=n - cap, replace=False)
            keep.loc[drop] = False
    return X[keep], y[keep], np.asarray(groups)[keep.values]


models, metrics, X_per_target, y_per_target = {}, {}, {}, {}

for target in BALL_FLIGHT_TARGETS:
    if target not in df.columns:
        continue
    cache = os.path.join(MODEL_DIR, f'lgbm_{SHOT_GROUP}_{target.replace(".","_")}.pkl')

    data = pd.concat([X_full, df[target]], axis=1).dropna()
    X_clean, y_clean = data[X_full.columns], data[target]
    g_clean = df.loc[X_clean.index, 'PlayerID'].values

    X_fit, y_fit, g_fit = cap_per_player(X_clean, y_clean, g_clean)

    # Always retrain to ensure feature compatibility with current X_full
    model = LGBMRegressor(n_estimators=500, learning_rate=0.05, random_state=42, verbose=-1)
    model.fit(X_fit, y_fit)
    joblib.dump(model, cache)
    src = 'trained'

    preds = model.predict(X_clean)
    r2_train = r2_score(y_clean, preds)
    mae = mean_absolute_error(y_clean, preds)
    rmse = np.sqrt(mean_squared_error(y_clean, preds))

    cv_est = LGBMRegressor(n_estimators=500, learning_rate=0.05, random_state=42, verbose=-1)
    r2_cv = float(np.mean(cross_val_score(
        cv_est, X_fit, y_fit,
        cv=GroupKFold(5).split(X_fit, y_fit, groups=g_fit),
        scoring='r2', n_jobs=-1
    )))

    models[target] = model
    metrics[target] = {'R2': r2_cv, 'R2_train': r2_train, 'MAE': mae, 'RMSE': rmse}
    X_per_target[target] = X_clean
    y_per_target[target] = y_clean

    flag = '' if r2_cv >= R2_MIN_FOR_DICE else f'  (below R²_MIN, DiCE will skip)'
    print(f'[{src}] {target:24s}  R²_cv={r2_cv:.3f}  R²_train={r2_train:.3f}  '
          f'MAE={mae:.4f}  RMSE={rmse:.4f}{flag}')

pd.DataFrame(metrics).T.round(4).style.background_gradient(subset=['R2'], cmap='RdYlGn')
# Out:
# [trained] Release.Height.Norm       R²_cv=0.676  R²_train=0.975  MAE=0.0003  RMSE=0.0004
# [trained] Initial.Ball.Angle        R²_cv=0.533  R²_train=0.887  MAE=0.8024  RMSE=1.4228
# [trained] Initial.Ball.Velocity     R²_cv=0.877  R²_train=0.976  MAE=0.0710  RMSE=0.1350
# [trained] Max.Ball.Arc              R²_cv=0.569  R²_train=0.956  MAE=0.0513  RMSE=0.0742
# <style type="text/css">
# #T_7f27b_row0_col0 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_7f27b_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_7f27b_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_7f27b_row3_col0 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7f27b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f27b_level0_col0" class="col_heading level0 col0" >R2</th>
#       <th id="T_7f27b_level0_col1" class="col_heading level0 col1" >R2_train</th>
#       <th id="T_7f27b_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_7f27b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f27b_level0_row0" class="row_heading level0 row0" >Release.Height.Norm</th>
#       <td id="T_7f27b_row0_col0" class="data row0 col0" >0.675800</td>
#       <td id="T_7f27b_row0_col1" class="data row0 col1" >0.974800</td>
#       <td id="T_7f27b_row0_col2" class="data row0 col2" >0.000300</td>
#       <td id="T_7f27b_row0_col3" class="data row0 col3" >0.000400</td>
#     </tr>
#     <tr>
#       <th id="T_7f27b_level0_row1" class="row_heading level0 row1" >Initial.Ball.Angle</th>
#       <td id="T_7f27b_row1_col0" class="data row1 col0" >0.532500</td>
#       <td id="T_7f27b_row1_col1" class="data row1 col1" >0.886700</td>
#       <td id="T_7f27b_row1_col2" class="data row1 col2" >0.802400</td>
#       <td id="T_7f27b_row1_col3" class="data row1 col3" >1.422800</td>
#     </tr>
#     <tr>
#       <th id="T_7f27b_level0_row2" class="row_heading level0 row2" >Initial.Ball.Velocity</th>
#       <td id="T_7f27b_row2_col0" class="data row2 col0" >0.876700</td>
#       <td id="T_7f27b_row2_col1" class="data row2 col1" >0.975800</td>
#       <td id="T_7f27b_row2_col2" class="data row2 col2" >0.071000</td>
#       <td id="T_7f27b_row2_col3" class="data row2 col3" >0.135000</td>
#     </tr>
#     <tr>
#       <th id="T_7f27b_level0_row3" class="row_heading level0 row3" >Max.Ball.Arc</th>
#       <td id="T_7f27b_row3_col0" class="data row3 col0" >0.568600</td>
#       <td id="T_7f27b_row3_col1" class="data row3 col1" >0.955900</td>
#       <td id="T_7f27b_row3_col2" class="data row3 col2" >0.051300</td>
#       <td id="T_7f27b_row3_col3" class="data row3 col3" >0.074200</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. Global SHAP — biomech features driving ball flight

# %%
SHAP_SAMPLE = 5000
shap_values_dict, explainers_dict, shap_samples_dict = {}, {}, {}

for target in BALL_FLIGHT_TARGETS:
    X = X_per_target[target]
    samp = X.sample(min(SHAP_SAMPLE, len(X)), random_state=42)
    expl = shap.TreeExplainer(models[target])
    sv = expl.shap_values(samp)
    shap_values_dict[target] = sv
    explainers_dict[target] = expl
    shap_samples_dict[target] = samp

# Cross-target ranking
ranks = []
for t in BALL_FLIGHT_TARGETS:
    s = pd.Series(np.abs(shap_values_dict[t]).mean(axis=0),
                  index=shap_samples_dict[t].columns, name=t)
    ranks.append(s)
cross_df = pd.concat(ranks, axis=1)
cross_df['mean_rank'] = cross_df.mean(axis=1)
cross_df = cross_df.sort_values('mean_rank', ascending=False)

biomech_cross = cross_df[cross_df.index.isin(BIOMECH_FEATURES)]

fig, ax = plt.subplots(figsize=(13, 7))
sns.heatmap(biomech_cross.head(15)[BALL_FLIGHT_TARGETS],
            cmap='YlOrRd', ax=ax, linewidths=0.4, annot=True, fmt='.3f',
            annot_kws={'size': 7})
ax.set_title('Mean |SHAP| — Top 15 Biomech Features × Ball Flight Targets', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Stage 2 — Ball Flight → Miss Distance
#
# One Random Forest per `(Shot.Location, Shot.Type)` group with `n ≥ 100`. This is the strongest layer of the chain — once a shot leaves the hand with measurable initial conditions, miss distance is highly predictable across all shot contexts.

# %%
PREDICTORS = ['Ball_to_Rim_Angle','Ball_Velocity','Release.Height.Norm',
              'Initial.Ball.Angle','Initial.Ball.Velocity','Max.Ball.Arc']
BDFC = 'Ball.Distance.from.Center'
MIN_N = 100

groups = []
for loc in df['Shot.Location'].unique():
    if loc == 'Free Throw':
        sub = df[df['Shot.Location'] == loc]
        if len(sub) >= MIN_N:
            groups.append((loc, 'All', sub))
    else:
        for st in df[df['Shot.Location'] == loc]['Shot.Type'].unique():
            sub = df[(df['Shot.Location'] == loc) & (df['Shot.Type'] == st)]
            if len(sub) >= MIN_N:
                groups.append((loc, st, sub))

rf_rows = []
for loc, st, sub in groups:
    data = sub[PREDICTORS + [BDFC]].dropna()
    if len(data) < MIN_N:
        continue
    rf = RandomForestRegressor(n_estimators=300, random_state=42, n_jobs=-1)
    rf.fit(data[PREDICTORS], data[BDFC])
    r2 = r2_score(data[BDFC], rf.predict(data[PREDICTORS]))

    sv = shap.TreeExplainer(rf).shap_values(data[PREDICTORS])
    abs_shap = pd.Series(np.abs(sv).mean(axis=0), index=PREDICTORS)
    signed_shap = pd.Series(sv.mean(axis=0), index=PREDICTORS)

    row = abs_shap.to_dict()
    row.update({f'{p}_signed': signed_shap[p] for p in PREDICTORS})
    row.update({'group': f'{loc} | {st}', 'r2': round(r2, 3), 'n': len(data)})
    rf_rows.append(row)

rf_df = pd.DataFrame(rf_rows)
print(f'{len(rf_df)} groups  |  R² range: {rf_df.r2.min():.3f}–{rf_df.r2.max():.3f}  '
      f'(median {rf_df.r2.median():.3f})')

# Signed SHAP heatmap -- direction matters for coaching
signed = rf_df.set_index('group')[[f'{p}_signed' for p in PREDICTORS]]
signed.columns = PREDICTORS
vmax = float(signed.abs().values.max())
fig, ax = plt.subplots(figsize=(12, max(6, len(signed)*0.4)))
sns.heatmap(signed, cmap='RdBu_r', center=0, vmin=-vmax, vmax=vmax,
            ax=ax, linewidths=0.4, annot=True, fmt='.3f', annot_kws={'size': 7})
ax.set_title('Signed SHAP — Ball Flight → Miss Distance, by Shot Context\n'
             'RED = increases miss (worse). BLUE = decreases miss (better).', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# 20 groups  |  R² range: 0.853–0.889  (median 0.873)

# %% [markdown]
# ## 7. Stage 3 sanity check — direct biomech → BDFC
#
# A parallel pipeline: skip ball flight entirely and predict miss distance directly from biomechanics. If this layer agrees with the indirect chain, we have a self-consistency check. If it's at noise floor, the indirect chain may be optimizing for a proxy that doesn't translate to outcomes.

# %%
bdfc_data = pd.concat([X_full, df[BDFC]], axis=1).dropna()
X_b = bdfc_data[X_full.columns]
y_b = bdfc_data[BDFC]
g_b = df.loc[X_b.index, 'PlayerID'].values

X_fit, y_fit, g_fit = cap_per_player(X_b, y_b, g_b)

bdfc_cache = os.path.join(MODEL_DIR, f'lgbm_{SHOT_GROUP}_BDFC.pkl')
if os.path.exists(bdfc_cache):
    bdfc_model = joblib.load(bdfc_cache)
else:
    bdfc_model = LGBMRegressor(n_estimators=500, learning_rate=0.05, random_state=42, verbose=-1)
    bdfc_model.fit(X_fit, y_fit)
    joblib.dump(bdfc_model, bdfc_cache)

r2_bdfc = float(np.mean(cross_val_score(
    LGBMRegressor(n_estimators=500, learning_rate=0.05, random_state=42, verbose=-1),
    X_fit, y_fit,
    cv=GroupKFold(5).split(X_fit, y_fit, groups=g_fit),
    scoring='r2', n_jobs=-1
)))
print(f'BDFC regressor — R²_cv = {r2_bdfc:.3f}  '
      f'(mean BDFC = {y_b.mean():.2f} cm, n = {len(y_b):,})')

# SHAP for the BDFC model
bdfc_sample = X_b.sample(min(5000, len(X_b)), random_state=42)
bdfc_sv = shap.TreeExplainer(bdfc_model).shap_values(bdfc_sample)

shap.summary_plot(bdfc_sv, bdfc_sample, max_display=15, show=False)
plt.title(f'Direct biomech → BDFC  (R²_cv = {r2_bdfc:.3f})', fontsize=12)
plt.tight_layout()
plt.show()

# Spearman: do the two pipelines agree on which biomech features matter?
direct = pd.Series(np.abs(bdfc_sv).mean(axis=0), index=bdfc_sample.columns)
direct = direct[direct.index.isin(BIOMECH_FEATURES)]
indirect = cross_df.loc[[c for c in cross_df.index if c in BIOMECH_FEATURES], 'mean_rank']
common = direct.index.intersection(indirect.index)
rho, p = spearmanr(direct.loc[common], indirect.loc[common])
print(f'\nSpearman ρ (direct vs indirect biomech rankings): {rho:.3f}  p={p:.3g}')
# Out:
# BDFC regressor — R²_cv = 0.007  (mean BDFC = 5.36 cm, n = 21,899)
# Spearman ρ (direct vs indirect biomech rankings): 0.657  p=8.08e-27

# %% [markdown]
# ## 8. Player analysis — Player 163
#
# Picked because he's the most-sampled player (2,873 jump shots, 13% of the dataset). Three lenses:
#
# 1. **Ball-flight scorecard** — does his actual median fall outside the made-shot optimal band on any metric?
# 2. **Make/miss self-comparison** — within his own shots, which biomech features differ between makes and misses? (Model-free; uses circular std for angular features so the ±180° wrap doesn't inflate effects.)
# 3. **Consistency vs role-matched peers** — for height-bucketed peers, where is he in the top quartile of shot-to-shot variance?
#
# A "priority" can be triggered by either the ball-flight gate (P1, P2, ...) or the self-compare gate (S1, S2, ...). The self-compare gate is critical here because Player 163 has *no* ball-flight gaps but a huge make/miss alignment delta.

# %%
PLAYER_ID = 'Player 163'
MIN_SHOTS = 20

p_mask = df.PlayerID == PLAYER_ID
p_shots = df[p_mask]
n_p = len(p_shots)
form_score = p_shots.Made.mean()
avg_miss = p_shots[BDFC].mean()

# Role-matched peers (height ± 3 in)
peers = df.copy()
if 'ht' in df.columns and p_shots.ht.notna().any():
    p_ht = float(p_shots.ht.median())
    peers = df[(df.ht.between(p_ht - 3, p_ht + 3)) & (df.PlayerID != PLAYER_ID)]
    peer_label = f'height {p_ht-3:.0f}–{p_ht+3:.0f} in'
else:
    peer_label = 'all players'

print(f'{PLAYER_ID} — {n_p:,} shots')
print(f'  Form score (test-shot make rate) : {form_score:.1%}  '
      f'(pool {df.Made.mean():.1%}, peers {peers.Made.mean():.1%})')
print(f'  Avg miss distance               : {avg_miss:.2f} cm  '
      f'(pool {df[BDFC].mean():.2f}, peers {peers[BDFC].mean():.2f})')
print(f'  Peer cohort                     : {peers.PlayerID.nunique()} players ({peer_label})')


def smart_std(s, name):
    s = pd.Series(s).dropna()
    if len(s) < 2:
        return float('nan')
    if 'alignment' in name.lower():
        return float(circstd(s.values, high=180, low=-180))
    return float(s.std())


# Make / miss self-comparison
# For circular alignment columns: summary uses circular_mean and delta uses
# shortest-arc circular_diff. Without this, a player whose makes cluster at
# +175 and misses at -175 would get a phantom +350 delta when the true arc
# distance is just 10 deg.
def _summary(values, name):
    """Robust summary: median for linear, circular mean for circular angles."""
    s = pd.Series(values).dropna()
    if len(s) == 0:
        return float('nan')
    return circular_mean(s.values) if is_circular(name) else float(s.median())

makes = p_shots[p_shots.Made == 1]
misses = p_shots[p_shots.Made == 0]
self_compare_rows = []
if len(makes) >= 5 and len(misses) >= 5:
    biomech_cols = [c for c in BIOMECH_FEATURES if c in p_shots.columns]
    for c in biomech_cols:
        make_s = _summary(makes[c], c)
        miss_s = _summary(misses[c], c)
        if pd.isna(make_s) or pd.isna(miss_s):
            continue
        if is_circular(c):
            delta = float(circular_diff(miss_s, make_s))
        else:
            delta = miss_s - make_s
        std = smart_std(p_shots[c], c)
        if pd.isna(std) or std == 0:
            continue
        eff = abs(delta) / std
        self_compare_rows.append({'feature': c,
                                  'make_median': float(make_s),
                                  'miss_median': float(miss_s),
                                  'delta': float(delta),
                                  'effect': float(eff)})
self_compare = pd.DataFrame(self_compare_rows).sort_values('effect', ascending=False)

print(f'\nMake/miss self-comparison: {len(makes)} makes vs {len(misses)} misses')
print(f'(Effect = |miss - make| / shot-to-shot std; circ-std for alignments)\n')
for _, r in self_compare.head(8).iterrows():
    flag = '  *' if r.effect >= 0.5 else ''
    print(f"  {r.feature:48s}  Δ={r.delta:+8.3f}  effect={r.effect:.2f}{flag}")

self_compare_priority = self_compare[self_compare.effect >= 0.5].to_dict('records')


# Consistency vs role-matched peers
biomech_cols = [c for c in BIOMECH_FEATURES if c in df.columns]
peer_qual = peers.PlayerID.value_counts()
peer_qual = peer_qual[peer_qual >= MIN_SHOTS].index.tolist()
cohort_ids = peer_qual + [PLAYER_ID]

cohort_stds = pd.DataFrame({
    pid: {c: smart_std(df[df.PlayerID == pid][c], c) for c in biomech_cols}
    for pid in cohort_ids
}).T

consistency_flags = []
if PLAYER_ID in cohort_stds.index and len(cohort_stds) >= 4:
    pctile = cohort_stds.rank(pct=True).loc[PLAYER_ID] * 100
    high = pctile[pctile >= 75].sort_values(ascending=False).head(8)
    if len(high) > 0:
        print(f'\nConsistency: top 25% of variance vs {len(peer_qual)} peers')
        for feat, p in high.items():
            std = float(cohort_stds.loc[PLAYER_ID, feat])
            if pd.isna(std):
                continue
            print(f"  {feat:48s}  std={std:7.3f}  ({p:.0f}th pctile)")
            consistency_flags.append({'feature': feat, 'player_std': std, 'pctile': float(p)})
# Out:
# Player 163 — 2,873 shots
#   Form score (test-shot make rate) : 64.1%  (pool 62.3%, peers 59.3%)
#   Avg miss distance               : 5.44 cm  (pool 5.36, peers 5.57)
#   Peer cohort                     : 82 players (height 79–85 in)
#
# Make/miss self-comparison: 1842 makes vs 1031 misses
# (Effect = |miss - make| / shot-to-shot std; circ-std for alignments)
#
#   maxTorsoFlexionHitch                              Δ=  -0.797  effect=0.27
#   maxAnkleDorsiflexionDominantPreHitch              Δ=  -1.927  effect=0.27
#   TorsoVeloPostHitch                                Δ=  +0.129  effect=0.26
#   maxTorsoExtensionPreHitch                         Δ=  -0.785  effect=0.26
#   MaxStanceGapRelease                               Δ=  -0.016  effect=0.25
#   BallVeloPreHitch                                  Δ=  +0.229  effect=0.25
#   maxAnkleDorsiflexionAvgPreHitch                   Δ=  -1.146  effect=0.23
#   maxAnklePlantarflexionDominantPreHitch            Δ=  -1.772  effect=0.22
#
# Consistency: top 25% of variance vs 69 peers
#   maxAnklePlantarflexionAvgPreHitch                 std=  5.673  (99th pctile)
#   ShoulderFlexionAtT0NonDominant                    std= 20.576  (99th pctile)
#   maxShoulderExtensionNonDominantPreHitch           std= 21.982  (99th pctile)
#   maxShoulderExtensionAvgPreHitch                   std= 18.297  (97th pctile)
#   ShoulderFlexionAtT0Dominant                       std= 16.778  (97th pctile)
#   maxElbowExtensionNonDominantPreHitch              std= 15.167  (97th pctile)
#   maxAnkleDorsiflexionAvgPreHitch                   std=  5.020  (97th pctile)
#   maxAnkleDorsiflexionDominantPreHitch              std=  7.238  (97th pctile)

# %%
# Ball-flight scorecard: actual-vs-actual, made-shot reference, optimal band
# A target qualifies as a priority only if:
#   1. player's actual median falls outside the 40-60 pctile of MADE shots
#   2. gap > max(2*SE_player, model RMSE)  -- statistically distinguishable
#   3. CV R² >= R2_MIN_FOR_DICE             -- model is good enough for a CF

weak_targets, scorecard = [], []

for target in BALL_FLIGHT_TARGETS:
    if target not in y_per_target:
        continue
    if is_circular(target):
        # Linear pctile is wrong for circular variables. None of the current
        # targets are circular; this guard is here so the scorecard fails loudly
        # if a circular target is added later.
        print(f'[skip] {target} is circular -- linear quantile band not implemented')
        continue
    X_t = X_per_target[target]
    pid_idx = df.loc[X_t.index, 'PlayerID'] == PLAYER_ID
    p_actual = df.loc[X_t.index, target][pid_idx].dropna()
    if len(p_actual) < MIN_SHOTS:
        continue

    actual_med = float(p_actual.median())
    se = (p_actual.std() / np.sqrt(len(p_actual))) if len(p_actual) > 1 else 0.0
    y_made = y_per_target[target][df.loc[X_t.index, 'Made'] == 1]
    lo, hi = float(y_made.quantile(0.40)), float(y_made.quantile(0.60))

    if actual_med < lo:
        gap, direction = lo - actual_med, 'increase'
    elif actual_med > hi:
        gap, direction = actual_med - hi, 'decrease'
    else:
        gap, direction = 0.0, 'in band'

    rmse = metrics[target]['RMSE']
    r2 = metrics[target]['R2']
    is_priority = gap > max(2*se, rmse) and r2 >= R2_MIN_FOR_DICE

    scorecard.append({
        'Metric': target, 'Player': round(actual_med, 3),
        'Optimal Lo': round(lo, 3), 'Optimal Hi': round(hi, 3),
        'Gap': round(gap, 3) if gap > 0 else '—',
        'CV R²': round(r2, 3),
        'Status': direction.upper() + (' *PRIORITY*' if is_priority else ''),
    })
    if is_priority:
        weak_targets.append(dict(target=target, actual_med=actual_med,
                                 target_lo=lo, target_hi=hi, gap=gap,
                                 rmse=rmse, r2=r2,
                                 direction=direction,
                                 X_player=X_t[pid_idx]))

display(pd.DataFrame(scorecard).style.hide(axis='index'))

# Headline drill targets — combines both gates
print(f"\n{'─'*70}\nHEADLINE DRILL TARGETS for {PLAYER_ID}\n{'─'*70}")
if not weak_targets and not self_compare_priority:
    print('No priority drills triggered — mechanics look sound on every gate.')
for i, wt in enumerate(weak_targets, 1):
    print(f"  P{i} (ball-flight): {wt['target']}, {wt['direction']} from "
          f"{wt['actual_med']:.3f} toward [{wt['target_lo']:.3f}, {wt['target_hi']:.3f}]")
for i, sp in enumerate(self_compare_priority, 1):
    print(f"  S{i} (self-compare): {sp['feature']}, "
          f"miss-make Δ={sp['delta']:+.2f}, effect={sp['effect']:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f59b7">
#   <thead>
#     <tr>
#       <th id="T_f59b7_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_f59b7_level0_col1" class="col_heading level0 col1" >Player</th>
#       <th id="T_f59b7_level0_col2" class="col_heading level0 col2" >Optimal Lo</th>
#       <th id="T_f59b7_level0_col3" class="col_heading level0 col3" >Optimal Hi</th>
#       <th id="T_f59b7_level0_col4" class="col_heading level0 col4" >Gap</th>
#       <th id="T_f59b7_level0_col5" class="col_heading level0 col5" >CV R²</th>
#       <th id="T_f59b7_level0_col6" class="col_heading level0 col6" >Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f59b7_row0_col0" class="data row0 col0" >Release.Height.Norm</td>
#       <td id="T_f59b7_row0_col1" class="data row0 col1" >0.033000</td>
#       <td id="T_f59b7_row0_col2" class="data row0 col2" >0.033000</td>
#       <td id="T_f59b7_row0_col3" class="data row0 col3" >0.033000</td>
#       <td id="T_f59b7_row0_col4" class="data row0 col4" >—</td>
#       <td id="T_f59b7_row0_col5" class="data row0 col5" >0.676000</td>
#       <td id="T_f59b7_row0_col6" class="data row0 col6" >IN BAND</td>
#     </tr>
#     <tr>
#       <td id="T_f59b7_row1_col0" class="data row1 col0" >Initial.Ball.Angle</td>
#       <td id="T_f59b7_row1_col1" class="data row1 col1" >45.564000</td>
#       <td id="T_f59b7_row1_col2" class="data row1 col2" >45.184000</td>
#       <td id="T_f59b7_row1_col3" class="data row1 col3" >46.568000</td>
#       <td id="T_f59b7_row1_col4" class="data row1 col4" >—</td>
#       <td id="T_f59b7_row1_col5" class="data row1 col5" >0.533000</td>
#       <td id="T_f59b7_row1_col6" class="data row1 col6" >IN BAND</td>
#     </tr>
#     <tr>
#       <td id="T_f59b7_row2_col0" class="data row2 col0" >Initial.Ball.Velocity</td>
#       <td id="T_f59b7_row2_col1" class="data row2 col1" >8.154000</td>
#       <td id="T_f59b7_row2_col2" class="data row2 col2" >8.159000</td>
#       <td id="T_f59b7_row2_col3" class="data row2 col3" >8.320000</td>
#       <td id="T_f59b7_row2_col4" class="data row2 col4" >0.005000</td>
#       <td id="T_f59b7_row2_col5" class="data row2 col5" >0.877000</td>
#       <td id="T_f59b7_row2_col6" class="data row2 col6" >INCREASE</td>
#     </tr>
#     <tr>
#       <td id="T_f59b7_row3_col0" class="data row3 col0" >Max.Ball.Arc</td>
#       <td id="T_f59b7_row3_col1" class="data row3 col1" >4.635000</td>
#       <td id="T_f59b7_row3_col2" class="data row3 col2" >4.534000</td>
#       <td id="T_f59b7_row3_col3" class="data row3 col3" >4.649000</td>
#       <td id="T_f59b7_row3_col4" class="data row3 col4" >—</td>
#       <td id="T_f59b7_row3_col5" class="data row3 col5" >0.569000</td>
#       <td id="T_f59b7_row3_col6" class="data row3 col6" >IN BAND</td>
#     </tr>
#   </tbody>
# </table>
# ──────────────────────────────────────────────────────────────────────
# HEADLINE DRILL TARGETS for Player 163
# ──────────────────────────────────────────────────────────────────────
# No priority drills triggered — mechanics look sound on every gate.

# %%
# Optional loop control for Sections 8/9/11 (mid-file)
# Default keeps existing single-player behavior.
RUN_ALL_PLAYERS = True
RUN_DICE_FOR_ALL = False
MAX_PLAYERS = None  # e.g., 10 for a smoke test

all_player_ids = sorted(df['PlayerID'].dropna().unique())
if MAX_PLAYERS is not None:
    all_player_ids = all_player_ids[:MAX_PLAYERS]

PLAYER_IDS_TO_PROCESS = all_player_ids if RUN_ALL_PLAYERS else [PLAYER_ID]

print(f'RUN_ALL_PLAYERS={RUN_ALL_PLAYERS} | RUN_DICE_FOR_ALL={RUN_DICE_FOR_ALL}')
print(f'Players queued: {len(PLAYER_IDS_TO_PROCESS)}')
if not RUN_ALL_PLAYERS:
    print(f'Single-player mode active: {PLAYER_ID}')
else:
    print('All-player mode active. Execute the optional batch cell after Section 11.')
# Out:
# RUN_ALL_PLAYERS=True | RUN_DICE_FOR_ALL=False
# Players queued: 165
# All-player mode active. Execute the optional batch cell after Section 11.

# %% [markdown]
# ## 9. Counterfactual recommendations
#
# For each ball-flight priority target, DiCE searches for the smallest set of biomech changes that pushes the predicted ball flight into the optimal band. Three layers of constraint:
#
# 1. **Empirical 5–95 pctile** — keeps suggestions in-distribution.
# 2. **Anatomical caps** — physiological limits per joint movement (e.g. elbow flexion ≤ 150°).
# 3. **Per-player feasibility** — bounded to the player's own observed range ± 0.5σ.
#
# Plus a kNN multivariate plausibility filter that rejects unrealistic feature combinations even when each individual value is in-range. Recommendations are sorted by `|change %| / coachability`, so ROM/alignment changes float to the top and peak-velocity changes (much harder to train) sink.

# %%
ANATOMICAL_BOUNDS = {
    ('elbow', 'flexion'):     (0, 150),   ('knee', 'flexion'):    (0, 140),
    ('hip', 'flexion'):       (0, 120),   ('shoulder', 'flexion'):(0, 180),
    ('ankle', 'dorsiflexion'):(-20, 30),  ('ankle','plantarflexion'):(-50, 0),
    ('torso', 'flexion'):     (-30, 90),  ('wrist', 'flexion'):   (-90, 90),
    ('alignment',):           (-180, 180),('rom',):               (0, 200),
    ('velocity',):            (-3000, 3000),
}

COACHABILITY = {'rom':1.0, 'alignment':1.0, 'flexion':0.9, 'extension':0.9,
                'velocity':0.3, 'velo':0.3}

def anatomical_bound(name):
    n = name.lower()
    for keys, (lo, hi) in ANATOMICAL_BOUNDS.items():
        if all(k in n for k in keys):
            return lo, hi
    return float('-inf'), float('inf')

def coachability(name):
    n = name.lower()
    for k, v in COACHABILITY.items():
        if k in n:
            return v
    return 0.5

def build_permitted_range(X, feats, player_X=None):
    """Per-feature permitted range for DiCE search.

    Linear features: empirical 5-95 pctile  AND  anatomical caps  AND  per-player feasibility.
    Circular features: linear quantiles are meaningless here (a player whose
    alignments cluster near +/-180 has linear pctiles of e.g. -160 to +160 which
    excludes nothing), so we use the full +/-180 range and rely on the
    self-compare gate (which has correct circular math) to drive recommendations.
    """
    out = {}
    for f in feats:
        if f not in X.columns:
            continue
        if is_circular(f):
            out[f] = [-180.0, 180.0]
            continue
        emp = (float(X[f].quantile(0.05)), float(X[f].quantile(0.95)))
        ana = anatomical_bound(f)
        lo, hi = max(emp[0], ana[0]), min(emp[1], ana[1])
        if player_X is not None and f in player_X.columns and len(player_X) > 0:
            pmin, pmax = float(player_X[f].min()), float(player_X[f].max())
            pstd = float(player_X[f].std()) if len(player_X) > 1 else 0
            lo = max(lo, pmin - 0.5*pstd)
            hi = min(hi, pmax + 0.5*pstd)
        if hi <= lo:
            lo, hi = emp
        out[f] = [lo, hi]
    return out

def make_plausibility_check(X_train, k=5, q=0.95):
    scaler = RobustScaler().fit(X_train.values)
    Xs = scaler.transform(X_train.values)
    nn = NearestNeighbors(n_neighbors=k).fit(Xs)
    in_d = nn.kneighbors(Xs)[0].mean(axis=1)
    threshold = float(np.quantile(in_d, q))
    def is_ok(row):
        d = float(nn.kneighbors(scaler.transform(np.asarray(row).reshape(1, -1)))[0].mean())
        return (d <= threshold), d, threshold
    return is_ok

cf_results, cf_top_feats = {}, {}

if not weak_targets:
    print('No ball-flight priority targets — DiCE skipped. (Self-compare priorities '
          'will still drive the Unity export.)')
else:
    for wt in weak_targets[:3]:
        target = wt['target']
        X_t, y_t, model_t = X_per_target[target], y_per_target[target], models[target]

        sv_all = shap_values_dict[target]
        X_samp = shap_samples_dict[target]
        mean_abs = pd.Series(np.abs(sv_all).mean(axis=0), index=X_samp.columns)
        top = [f for f in mean_abs.sort_values(ascending=False).index
               if f in BIOMECH_FEATURES and f in X_t.columns
               and not is_circular(f)][:10]   # circular cols handled by self-compare gate
        cf_top_feats[target] = top

        perm = build_permitted_range(X_t, top, player_X=wt['X_player'])

        made_p = df.loc[wt['X_player'].index, 'Made'] == 1
        query = (wt['X_player'][made_p].median().to_frame().T if made_p.sum() >= 5
                 else wt['X_player'].median().to_frame().T)

        dice_df = pd.concat([X_t, y_t], axis=1).dropna().sample(
            min(2000, len(X_t)), random_state=42).reset_index(drop=True)
        d_dice = dice_ml.Data(dataframe=dice_df,
                              continuous_features=list(X_t.columns),
                              outcome_name=target)
        m_dice = dice_ml.Model(model=model_t, backend='sklearn', model_type='regressor')
        exp_dice = dice_ml.Dice(d_dice, m_dice, method='genetic')

        np.random.seed(42)
        try:
            cf = exp_dice.generate_counterfactuals(
                query_instances=query, total_CFs=3,
                desired_range=[wt['target_lo'], wt['target_hi']],
                features_to_vary=top, permitted_range=perm,
            )
            cf_results[target] = cf
            print(f"\n── DiCE: {target} ──")
            print(f"  current {wt['actual_med']:.3f} → optimal "
                  f"[{wt['target_lo']:.3f}, {wt['target_hi']:.3f}]")
            cf.visualize_as_dataframe(show_only_changes=True)
        except Exception as e:
            print(f'  DiCE failed: {e}')
            cf_results[target] = None
# Out:
# No ball-flight priority targets — DiCE skipped. (Self-compare priorities will still drive the Unity export.)

# %% [markdown]
# ## 10. Free-throw sanity check
#
# Free throws are the cleanest possible test for biomechanics → outcome: same distance every time, no defense, no movement. If `R²` is at noise floor here too, the marker-based device is categorically blind to the release-point dynamics that drive accuracy — not just movement-related ones.

# %%
ft = standardize_handedness(df_raw)
ft[ft.select_dtypes('number').columns] = ft.select_dtypes('number').mask(
    ft.select_dtypes('number').abs() > 1e6)
ft = ft[ft['Shot.Location'] == 'Free Throw'].copy()
if {'Release.Height', 'ht'}.issubset(ft.columns):
    ft['Release.Height.Norm'] = ft['Release.Height'] / ft['ht']

bio_ft = [c for c in BIOMECH_FEATURES if c in ft.columns]
ft = add_within_player(ft, bio_ft)
zw_ft = [f'{c}__zwithin' for c in bio_ft if f'{c}__zwithin' in ft.columns]
X_ft = ft[bio_ft + zw_ft]

print(f'FT: {len(ft):,} shots, {ft.PlayerID.nunique()} players, {X_ft.shape[1]} features\n')

ft_results = {}
for target in BALL_FLIGHT_TARGETS + [BDFC]:
    if target not in ft.columns:
        continue
    data = pd.concat([X_ft, ft[target]], axis=1).dropna()
    X_c, y_c = data[X_ft.columns], data[target]
    g_c = ft.loc[X_c.index, 'PlayerID'].values
    if len(set(g_c)) < 5:
        continue
    X_fit, y_fit, g_fit = cap_per_player(X_c, y_c, g_c)
    est = LGBMRegressor(n_estimators=500, learning_rate=0.05, random_state=42, verbose=-1)
    r2 = float(np.mean(cross_val_score(
        est, X_fit, y_fit,
        cv=GroupKFold(min(5, len(set(g_fit)))).split(X_fit, y_fit, groups=g_fit),
        scoring='r2', n_jobs=-1)))
    ft_results[target] = r2
    print(f'  FT  {target:28s}  R²_cv = {r2:.3f}')

# Side-by-side table
print(f'\n{"Target":<30s}  {"JumpShots":>10s}  {"FreeThrow":>10s}  {"Δ":>8s}')
print(f'{"-"*30}  {"-"*10}  {"-"*10}  {"-"*8}')
for t in BALL_FLIGHT_TARGETS:
    js = metrics.get(t, {}).get('R2', float('nan'))
    f_ = ft_results.get(t, float('nan'))
    print(f'  {t:<28s}  {js:>10.3f}  {f_:>10.3f}  {f_-js:>+8.3f}')
print(f'  {"BDFC":<28s}  {r2_bdfc:>10.3f}  {ft_results.get(BDFC, float("nan")):>10.3f}  '
      f'{ft_results.get(BDFC, 0)-r2_bdfc:>+8.3f}')
# Out:
# FT: 3,967 shots, 136 players, 412 features
#
#   FT  Release.Height.Norm           R²_cv = 0.112
#   FT  Initial.Ball.Angle            R²_cv = 0.302
#   FT  Initial.Ball.Velocity         R²_cv = 0.280
#   FT  Max.Ball.Arc                  R²_cv = 0.199
#   FT  Ball.Distance.from.Center     R²_cv = -0.076
#
# Target                           JumpShots   FreeThrow         Δ
# ------------------------------  ----------  ----------  --------
#   Release.Height.Norm                0.676       0.112    -0.564
#   Initial.Ball.Angle                 0.533       0.302    -0.230
#   Initial.Ball.Velocity              0.877       0.280    -0.597
#   Max.Ball.Arc                       0.569       0.199    -0.370
#   BDFC                               0.007      -0.076    -0.082

# %% [markdown]
# ## 11. Unity export
#
# For the 3D-skeleton visualization. Each row is one shot with two pose blocks side-by-side: `orig_*` (the actual biomech values) and `rec_*` (the original with priority features replaced by the player's makes-baseline or DiCE counterfactual). Non-priority columns are identical between the two so the viewer sees only the recommended changes.
#
# Note: the CSV has no joint XYZ coordinates — Unity needs to drive a parametric humanoid avatar (built-in Humanoid rig, Mixamo, etc.) from the joint angles via IK. Player height (`ht`) scales the rig.

# %%
def is_circular(feat_name):
    """Identify if a feature is angular/circular based on its name."""
    circular_keywords = ['Angle', 'Rotation', 'Direction', 'Alignment']
    return any(keyword in feat_name for keyword in circular_keywords)

def circular_unwrap(orig_vals, target_val):
    """
    Unwrap target_val so that the difference (target_val - orig_vals) 
    is in the shortest path [-180, 180]. 
    Assumes values are in degrees.
    """
    diff_deg = (target_val - orig_vals + 180) % 360 - 180
    return orig_vals + diff_deg

def cap_realistic_change(param_name, orig_val, target_val):
    """
    Cap the recommended changes to biomechanically realistic maximums.
    Athletes cannot physically alter mechanics by 40+ degrees in one go safely.
    """
    if pd.isna(orig_val) or pd.isna(target_val):
        return target_val
        
    delta = target_val - orig_val
    
    if any(k in param_name for k in ['Angle', 'Flexion', 'Extension', 'Abduction', 'Rotation', 'Tilt', 'Sway']):
        # Max 12 degrees angular adjustment per cue
        max_delta = 12.0
    elif 'Velo' in param_name or 'Velocity' in param_name:
        max_delta = max(0.5, abs(orig_val) * 0.20)
    else:
        max_delta = abs(orig_val) * 0.20
        
    if abs(delta) > max_delta:
        return orig_val + (np.sign(delta) * max_delta)
    
    return target_val


def build_unity_export(player_id, df_all, models, explainers_dict, X_per_target, 
                       y_per_target, shot_group, output_dir="unity_exports", n_top=5):
    """
    Dumps a flat CSV where EACH ROW = 1 SHOT.
    Matches the batch runner signature. Generates SHAP dynamically per shot.
    Targets are grouped by Shot.Type and constrained to realistic deltas.
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 1. Filter to player
    df_player = df_all[df_all['PlayerID'] == player_id].copy()
    if df_player.empty:
        return pd.DataFrame()
        
    # BDFC is the make/miss target metric
    target = 'Made' if 'Made' in df_all.columns else BDFC
    if target not in X_per_target or target not in models or target not in explainers_dict:
        # Fallback if names differ
        target = list(models.keys())[-1]
    
    # Get valid indices only
    valid_idx = df_player.index.intersection(X_per_target[target].index)
    if valid_idx.empty:
        return pd.DataFrame()
        
    df_player = df_player.loc[valid_idx]
    
    X_t = X_per_target[target].loc[valid_idx]
    y_t = y_per_target[target].loc[valid_idx] if target in y_per_target else df_player['Made']
    
    model = models[target]
    explainer = explainers_dict[target]
    
    # Predict makes
    preds = model.predict(X_t)
    # Threshold at 0.5 if classification conceptually, or just use actual Made logic
    make_preds = (preds > np.median(preds)).astype(int) if len(np.unique(y_t))>2 else (preds > 0.5).astype(int)
    
    pose_cols = X_t.columns.tolist()
    
    # Calculate global & type-specific medians for successful shots ONLY from X_t features
    makes_idx = df_player[df_player["Made"] == 1].index
    global_makes_median = X_t.loc[makes_idx].median().to_dict()
    
    type_makes_median = {}
    if "Shot.Type" in df_player.columns:
        grouped = df_player.loc[makes_idx].groupby("Shot.Type")
        for stype, group in grouped:
            if len(group) >= 3:
                type_makes_median[stype] = X_t.loc[group.index].median().to_dict()
                
    def get_makes_median(shot_type, feat):
        if shot_type in type_makes_median and feat in type_makes_median[shot_type]:
            return type_makes_median[shot_type][feat]
        return global_makes_median.get(feat, None)

    # Calculate SHAP values
    shap_vals = explainer.shap_values(X_t)
    if isinstance(shap_vals, list):
        shap_vals = shap_vals[1]

    export_rows = []
    
    for shot_idx, (idx, shot_row) in enumerate(df_player.iterrows()):
        
        # Only recommend for predicted misses
        if make_preds[shot_idx] == 1:
            continue
            
        sv_row = shap_vals[shot_idx, :]
        # Features hurting the shot (negative SHAP impact)
        hurting_mask = sv_row < 0
        if not hurting_mask.any():
            continue
            
        # Get top negative effect features, strictly ignoring non-coachable context variables
        feat_impacts = pd.Series(np.abs(sv_row[hurting_mask]), index=X_t.columns[hurting_mask])
        coachable_cols = [c for c in feat_impacts.index if "Distance" not in c and "Type" not in c and "Year" not in c and "Days" not in c]
        feat_impacts = feat_impacts.loc[coachable_cols]
        top_feats = feat_impacts.sort_values(ascending=False).head(n_top).index.tolist()
        
        shot_type = shot_row.get("Shot.Type", "Unknown")
            
        # Build orig / rec pose rows
        orig_pose, rec_pose = {}, {}
        for col in pose_cols:
            orig_val = X_t.loc[idx, col]
            orig_pose[f'orig_{col}'] = orig_val
            if col in top_feats:
                tval = get_makes_median(shot_type, col)
                if tval is not None:
                    raw_target = (
                        float(circular_unwrap(np.array([orig_val]), tval)[0])
                        if is_circular(col) else tval
                    )
                    rec_pose[f'rec_{col}'] = cap_realistic_change(col, orig_val, raw_target)
                else:
                    rec_pose[f'rec_{col}'] = orig_val
            else:
                rec_pose[f'rec_{col}'] = orig_val
                
        row_dict = {
            'PlayerId': player_id,
            'ShotId': shot_row.get('ShotId', idx),
            'Shot.Type': shot_type,
            'Prediction': make_preds[shot_idx],
            'is_make': y_t.loc[idx],
            'Top_Feats': ", ".join(top_feats)
        }
        
        row_dict.update(orig_pose)
        row_dict.update(rec_pose)
        export_rows.append(row_dict)

    df_export = pd.DataFrame(export_rows)
    out_path = os.path.join(output_dir, f"unity_export_Player_{player_id}.csv")
    df_export.to_csv(out_path, index=False)
    return df_export

# %%
def build_skeleton_export(player_id, df_all, models, explainers_dict,
                          X_per_target, y_per_target, shot_group,
                          output_dir="skeleton_exports", n_top=5):
    """
    Slim export for the 3D skeleton visualizer.
    Each row = one predicted-miss shot with up to n_top correction deltas.
    """
    os.makedirs(output_dir, exist_ok=True)

    df_player = df_all[df_all['PlayerID'] == player_id].copy()
    if df_player.empty:
        return pd.DataFrame()

    target = 'Made' if 'Made' in df_all.columns else BDFC
    if target not in X_per_target or target not in models or target not in explainers_dict:
        target = list(models.keys())[-1]

    valid_idx = df_player.index.intersection(X_per_target[target].index)
    if valid_idx.empty:
        return pd.DataFrame()

    df_player = df_player.loc[valid_idx]
    X_t = X_per_target[target].loc[valid_idx]
    y_t = y_per_target[target].loc[valid_idx] if target in y_per_target else df_player['Made']

    model = models[target]
    explainer = explainers_dict[target]

    preds = model.predict(X_t)
    make_preds = ((preds > np.median(preds)).astype(int)
                  if len(np.unique(y_t)) > 2
                  else (preds > 0.5).astype(int))

    player_hand_mode = df_player['hand'].mode()
    player_hand = player_hand_mode.iloc[0] if len(player_hand_mode) > 0 else 'Right'
    
    makes_idx = df_player[df_player["Made"] == 1].index
    global_makes_med = X_t.loc[makes_idx].median().to_dict() if len(makes_idx) > 0 else {}

    type_makes_med = {}
    if "Shot.Type" in df_player.columns:
        for stype, group in df_player.loc[makes_idx].groupby("Shot.Type"):
            if len(group) >= 3:
                type_makes_med[stype] = X_t.loc[group.index].median().to_dict()

    def get_target_val(shot_type, feat):
        if shot_type in type_makes_med and feat in type_makes_med[shot_type]:
            return type_makes_med[shot_type][feat]
        return global_makes_med.get(feat, None)

    shap_vals = explainer.shap_values(X_t)
    if isinstance(shap_vals, list):
        shap_vals = shap_vals[1]

    export_rows = []

    for shot_idx, (idx, shot_row) in enumerate(df_player.iterrows()):
        if make_preds[shot_idx] == 1:
            continue

        sv_row = shap_vals[shot_idx, :]
        hurting_mask = sv_row < 0
        if not hurting_mask.any():
            continue

        feat_impacts = pd.Series(np.abs(sv_row[hurting_mask]), index=X_t.columns[hurting_mask])
        coachable = [c for c in feat_impacts.index
                     if not any(k in c for k in ["Distance", "Type", "Year", "Days"])]
        feat_impacts = feat_impacts.loc[coachable]
        top_feats = feat_impacts.sort_values(ascending=False).head(n_top).index.tolist()

        shot_type = shot_row.get("Shot.Type", "Unknown")

        row_dict = {
            'PlayerId':  player_id,
            'ShotId':    shot_row.get('ShotId', idx),
            'Shot.Type': shot_type,
            'hand':      player_hand,
            'is_make':   int(y_t.loc[idx]),
        }

        for rank, feat in enumerate(top_feats, 1):
            orig_val = float(X_t.loc[idx, feat])
            tval = get_target_val(shot_type, feat)

            if tval is not None:
                if is_circular(feat):
                    raw_target = float(circular_unwrap(np.array([orig_val]), tval)[0])
                else:
                    raw_target = float(tval)
                rec_val = cap_realistic_change(feat, orig_val, raw_target)
            else:
                rec_val = orig_val

            delta = rec_val - orig_val
            row_dict[f'feat_{rank}']  = feat
            row_dict[f'orig_{rank}']  = round(orig_val, 3)
            row_dict[f'rec_{rank}']   = round(rec_val, 3)
            row_dict[f'delta_{rank}'] = round(delta, 3)

        export_rows.append(row_dict)

    df_export = pd.DataFrame(export_rows)
    out_path = os.path.join(output_dir, f"skeleton_export_{player_id}.csv")
    df_export.to_csv(out_path, index=False)
    print(f"Exported {len(df_export)} shots for {player_id} → {out_path}")
    return df_export

# %%
# Optional all-player batch runner (execute after Section 11)
# Runs Sections 8/11 per player when RUN_ALL_PLAYERS=True.
# DiCE removed: per-shot SHAP in build_unity_export replaces it.


def run_batch_player_recommendations(player_ids, verbose=True):
    all_outputs = {}
    all_unity   = {}

    for idx, pid in enumerate(player_ids, 1):
        p_shots = df[df.PlayerID == pid]
        makes   = p_shots[p_shots.Made == 1]
        misses  = p_shots[p_shots.Made == 0]

        # Lightweight self-compare (diagnostic only; not passed to export)
        self_compare_rows = []
        if len(makes) >= 5 and len(misses) >= 5:
            for col in [c for c in BIOMECH_FEATURES if c in p_shots.columns]:
                if is_circular(col):
                    make_s = circular_mean(makes[col].dropna().values)
                    miss_s = circular_mean(misses[col].dropna().values)
                    delta  = float(circular_diff(miss_s, make_s))
                else:
                    make_s = float(makes[col].median())
                    miss_s = float(misses[col].median())
                    delta  = miss_s - make_s
                std = smart_std(p_shots[col], col)
                if pd.isna(std) or std == 0:
                    continue
                self_compare_rows.append({
                    'feature': col,
                    'make_median': float(make_s),
                    'miss_median': float(miss_s),
                    'delta':       float(delta),
                    'effect':      abs(delta) / std,
                })
        sc_df = (
            pd.DataFrame(self_compare_rows).sort_values('effect', ascending=False)
            if self_compare_rows
            else pd.DataFrame(columns=['feature','make_median','miss_median','delta','effect'])
        )

        # Ball-flight scorecard (diagnostic only)
        weak_targets_local = []
        for target in BALL_FLIGHT_TARGETS:
            if target not in y_per_target:
                continue
            X_t     = X_per_target[target]
            pid_idx = df.loc[X_t.index, 'PlayerID'] == pid
            p_actual = df.loc[X_t.index, target][pid_idx].dropna()
            if len(p_actual) < MIN_SHOTS:
                continue
            actual_med = float(p_actual.median())
            se = (p_actual.std() / np.sqrt(len(p_actual))) if len(p_actual) > 1 else 0.0
            y_made = y_per_target[target][df.loc[X_t.index, 'Made'] == 1]
            lo, hi = float(y_made.quantile(0.40)), float(y_made.quantile(0.60))
            gap = max(lo - actual_med, 0.0) if actual_med < lo else max(actual_med - hi, 0.0)
            if gap > max(2 * se, metrics[target]['RMSE']) and metrics[target]['R2'] >= R2_MIN_FOR_DICE:
                weak_targets_local.append(target)

        # Per-shot SHAP export (the actual deliverable output)
        unity_local = build_skeleton_export(
            pid, df,
            models=models,
            explainers_dict=explainers_dict,
            X_per_target=X_per_target,
            y_per_target=y_per_target,
            shot_group=SHOT_GROUP,
        )

        all_outputs[pid] = {
            'weak_targets':        weak_targets_local,
            'self_compare_priority': sc_df[sc_df.effect >= 0.5].to_dict('records'),
        }
        all_unity[pid] = unity_local

        if verbose:
            print(f'[{idx}/{len(player_ids)}] {pid}: '
                  f'weak_targets={len(weak_targets_local)} | '
                  f'unity_rows={len(unity_local)}')

    return all_outputs, all_unity


if RUN_ALL_PLAYERS:
    batch_outputs, batch_unity = run_batch_player_recommendations(
        PLAYER_IDS_TO_PROCESS, verbose=True,
    )
    print(f'Batch completed for {len(batch_outputs)} players.')
else:
    print('Batch runner idle (RUN_ALL_PLAYERS=False).')
# Out:
# Exported 29 shots for Player 1 → skeleton_exports/skeleton_export_Player 1.csv
# [1/165] Player 1: weak_targets=2 | unity_rows=29
# Exported 49 shots for Player 10 → skeleton_exports/skeleton_export_Player 10.csv
# [2/165] Player 10: weak_targets=3 | unity_rows=49
# Exported 0 shots for Player 100 → skeleton_exports/skeleton_export_Player 100.csv
# [3/165] Player 100: weak_targets=0 | unity_rows=0
# Exported 40 shots for Player 101 → skeleton_exports/skeleton_export_Player 101.csv
# [4/165] Player 101: weak_targets=2 | unity_rows=40
# Exported 697 shots for Player 102 → skeleton_exports/skeleton_export_Player 102.csv
# [5/165] Player 102: weak_targets=1 | unity_rows=697
# Exported 137 shots for Player 103 → skeleton_exports/skeleton_export_Player 103.csv
# [6/165] Player 103: weak_targets=0 | unity_rows=137
# Exported 59 shots for Player 104 → skeleton_exports/skeleton_export_Player 104.csv
# [7/165] Player 104: weak_targets=2 | unity_rows=59
# Exported 28 shots for Player 105 → skeleton_exports/skeleton_export_Player 105.csv
# [8/165] Player 105: weak_targets=2 | unity_rows=28
# Exported 27 shots for Player 106 → skeleton_exports/skeleton_export_Player 106.csv
# [9/165] Player 106: weak_targets=3 | unity_rows=27
# Exported 15 shots for Player 107 → skeleton_exports/skeleton_export_Player 107.csv
# [10/165] Player 107: weak_targets=1 | unity_rows=15
# Exported 27 shots for Player 108 → skeleton_exports/skeleton_export_Player 108.csv
# [11/165] Player 108: weak_targets=2 | unity_rows=27
# Exported 24 shots for Player 109 → skeleton_exports/skeleton_export_Player 109.csv
# [12/165] Player 109: weak_targets=1 | unity_rows=24
# Exported 2 shots for Player 11 → skeleton_exports/skeleton_export_Player 11.csv
# [13/165] Player 11: weak_targets=0 | unity_rows=2
# Exported 38 shots for Player 110 → skeleton_exports/skeleton_export_Player 110.csv
# [14/165] Player 110: weak_targets=0 | unity_rows=38
# Exported 56 shots for Player 111 → skeleton_exports/skeleton_export_Player 111.csv
# [15/165] Player 111: weak_targets=2 | unity_rows=56
# Exported 42 shots for Player 112 → skeleton_exports/skeleton_export_Player 112.csv
# [16/165] Player 112: weak_targets=3 | unity_rows=42
# Exported 54 shots for Player 113 → skeleton_exports/skeleton_export_Player 113.csv
# [17/165] Player 113: weak_targets=1 | unity_rows=54
# Exported 41 shots for Player 114 → skeleton_exports/skeleton_export_Player 114.csv
# [18/165] Player 114: weak_targets=0 | unity_rows=41
# Exported 41 shots for Player 115 → skeleton_exports/skeleton_export_Player 115.csv
# [19/165] Player 115: weak_targets=2 | unity_rows=41
# Exported 253 shots for Player 116 → skeleton_exports/skeleton_export_Player 116.csv
# [20/165] Player 116: weak_targets=1 | unity_rows=253
# Exported 38 shots for Player 117 → skeleton_exports/skeleton_export_Player 117.csv
# [21/165] Player 117: weak_targets=1 | unity_rows=38
# Exported 37 shots for Player 118 → skeleton_exports/skeleton_export_Player 118.csv
# [22/165] Player 118: weak_targets=2 | unity_rows=37
# Exported 14 shots for Player 119 → skeleton_exports/skeleton_export_Player 119.csv
# [23/165] Player 119: weak_targets=2 | unity_rows=14
# Exported 62 shots for Player 12 → skeleton_exports/skeleton_export_Player 12.csv
# [24/165] Player 12: weak_targets=2 | unity_rows=62
# Exported 200 shots for Player 120 → skeleton_exports/skeleton_export_Player 120.csv
# [25/165] Player 120: weak_targets=3 | unity_rows=200
# Exported 41 shots for Player 121 → skeleton_exports/skeleton_export_Player 121.csv
# [26/165] Player 121: weak_targets=2 | unity_rows=41
# Exported 26 shots for Player 122 → skeleton_exports/skeleton_export_Player 122.csv
# [27/165] Player 122: weak_targets=0 | unity_rows=26
# Exported 26 shots for Player 123 → skeleton_exports/skeleton_export_Player 123.csv
# [28/165] Player 123: weak_targets=2 | unity_rows=26
# Exported 42 shots for Player 124 → skeleton_exports/skeleton_export_Player 124.csv
# [29/165] Player 124: weak_targets=2 | unity_rows=42
# Exported 141 shots for Player 125 → skeleton_exports/skeleton_export_Player 125.csv
# [30/165] Player 125: weak_targets=1 | unity_rows=141
# Exported 89 shots for Player 126 → skeleton_exports/skeleton_export_Player 126.csv
# [31/165] Player 126: weak_targets=0 | unity_rows=89
# Exported 37 shots for Player 127 → skeleton_exports/skeleton_export_Player 127.csv
# [32/165] Player 127: weak_targets=2 | unity_rows=37
# Exported 38 shots for Player 128 → skeleton_exports/skeleton_export_Player 128.csv
# [33/165] Player 128: weak_targets=1 | unity_rows=38
# Exported 5 shots for Player 129 → skeleton_exports/skeleton_export_Player 129.csv
# [34/165] Player 129: weak_targets=0 | unity_rows=5
# Exported 99 shots for Player 13 → skeleton_exports/skeleton_export_Player 13.csv
# [35/165] Player 13: weak_targets=1 | unity_rows=99
# Exported 39 shots for Player 130 → skeleton_exports/skeleton_export_Player 130.csv
# [36/165] Player 130: weak_targets=2 | unity_rows=39
# Exported 0 shots for Player 131 → skeleton_exports/skeleton_export_Player 131.csv
# [37/165] Player 131: weak_targets=0 | unity_rows=0
# Exported 40 shots for Player 132 → skeleton_exports/skeleton_export_Player 132.csv
# [38/165] Player 132: weak_targets=0 | unity_rows=40
# Exported 102 shots for Player 133 → skeleton_exports/skeleton_export_Player 133.csv
# [39/165] Player 133: weak_targets=3 | unity_rows=102
# Exported 42 shots for Player 134 → skeleton_exports/skeleton_export_Player 134.csv
# [40/165] Player 134: weak_targets=0 | unity_rows=42
# Exported 41 shots for Player 135 → skeleton_exports/skeleton_export_Player 135.csv
# [41/165] Player 135: weak_targets=1 | unity_rows=41
# Exported 8 shots for Player 136 → skeleton_exports/skeleton_export_Player 136.csv
# [42/165] Player 136: weak_targets=0 | unity_rows=8
# Exported 14 shots for Player 137 → skeleton_exports/skeleton_export_Player 137.csv
# [43/165] Player 137: weak_targets=1 | unity_rows=14
# Exported 4 shots for Player 138 → skeleton_exports/skeleton_export_Player 138.csv
# [44/165] Player 138: weak_targets=0 | unity_rows=4
# Exported 58 shots for Player 139 → skeleton_exports/skeleton_export_Player 139.csv
# [45/165] Player 139: weak_targets=1 | unity_rows=58
# Exported 37 shots for Player 14 → skeleton_exports/skeleton_export_Player 14.csv
# [46/165] Player 14: weak_targets=1 | unity_rows=37
# Exported 40 shots for Player 140 → skeleton_exports/skeleton_export_Player 140.csv
# [47/165] Player 140: weak_targets=2 | unity_rows=40
# Exported 4 shots for Player 141 → skeleton_exports/skeleton_export_Player 141.csv
# [48/165] Player 141: weak_targets=0 | unity_rows=4
# Exported 0 shots for Player 142 → skeleton_exports/skeleton_export_Player 142.csv
# [49/165] Player 142: weak_targets=0 | unity_rows=0
# Exported 59 shots for Player 143 → skeleton_exports/skeleton_export_Player 143.csv
# [50/165] Player 143: weak_targets=2 | unity_rows=59
# Exported 37 shots for Player 144 → skeleton_exports/skeleton_export_Player 144.csv
# [51/165] Player 144: weak_targets=1 | unity_rows=37
# Exported 109 shots for Player 145 → skeleton_exports/skeleton_export_Player 145.csv
# [52/165] Player 145: weak_targets=2 | unity_rows=109
# Exported 24 shots for Player 146 → skeleton_exports/skeleton_export_Player 146.csv
# [53/165] Player 146: weak_targets=2 | unity_rows=24
# Exported 64 shots for Player 147 → skeleton_exports/skeleton_export_Player 147.csv
# [54/165] Player 147: weak_targets=2 | unity_rows=64
# Exported 5 shots for Player 148 → skeleton_exports/skeleton_export_Player 148.csv
# [55/165] Player 148: weak_targets=0 | unity_rows=5
# Exported 61 shots for Player 149 → skeleton_exports/skeleton_export_Player 149.csv
# [56/165] Player 149: weak_targets=2 | unity_rows=61
# Exported 31 shots for Player 15 → skeleton_exports/skeleton_export_Player 15.csv
# [57/165] Player 15: weak_targets=0 | unity_rows=31
# Exported 47 shots for Player 150 → skeleton_exports/skeleton_export_Player 150.csv
# [58/165] Player 150: weak_targets=3 | unity_rows=47
# Exported 3 shots for Player 151 → skeleton_exports/skeleton_export_Player 151.csv
# [59/165] Player 151: weak_targets=0 | unity_rows=3
# Exported 0 shots for Player 152 → skeleton_exports/skeleton_export_Player 152.csv
# [60/165] Player 152: weak_targets=0 | unity_rows=0
# Exported 44 shots for Player 153 → skeleton_exports/skeleton_export_Player 153.csv
# [61/165] Player 153: weak_targets=2 | unity_rows=44
# Exported 72 shots for Player 154 → skeleton_exports/skeleton_export_Player 154.csv
# [62/165] Player 154: weak_targets=2 | unity_rows=72
# Exported 18 shots for Player 155 → skeleton_exports/skeleton_export_Player 155.csv
# [63/165] Player 155: weak_targets=2 | unity_rows=18
# Exported 64 shots for Player 156 → skeleton_exports/skeleton_export_Player 156.csv
# [64/165] Player 156: weak_targets=1 | unity_rows=64
# Exported 67 shots for Player 157 → skeleton_exports/skeleton_export_Player 157.csv
# [65/165] Player 157: weak_targets=1 | unity_rows=67
# Exported 561 shots for Player 158 → skeleton_exports/skeleton_export_Player 158.csv
# [66/165] Player 158: weak_targets=2 | unity_rows=561
# Exported 32 shots for Player 159 → skeleton_exports/skeleton_export_Player 159.csv
# [67/165] Player 159: weak_targets=1 | unity_rows=32
# Exported 37 shots for Player 16 → skeleton_exports/skeleton_export_Player 16.csv
# [68/165] Player 16: weak_targets=3 | unity_rows=37
# Exported 38 shots for Player 160 → skeleton_exports/skeleton_export_Player 160.csv
# [69/165] Player 160: weak_targets=2 | unity_rows=38
# Exported 42 shots for Player 161 → skeleton_exports/skeleton_export_Player 161.csv
# [70/165] Player 161: weak_targets=1 | unity_rows=42
# Exported 35 shots for Player 162 → skeleton_exports/skeleton_export_Player 162.csv
# [71/165] Player 162: weak_targets=0 | unity_rows=35
# Exported 1436 shots for Player 163 → skeleton_exports/skeleton_export_Player 163.csv
# [72/165] Player 163: weak_targets=0 | unity_rows=1436
# Exported 37 shots for Player 164 → skeleton_exports/skeleton_export_Player 164.csv
# [73/165] Player 164: weak_targets=3 | unity_rows=37
# Exported 37 shots for Player 165 → skeleton_exports/skeleton_export_Player 165.csv
# [74/165] Player 165: weak_targets=1 | unity_rows=37
# Exported 13 shots for Player 17 → skeleton_exports/skeleton_export_Player 17.csv
# [75/165] Player 17: weak_targets=3 | unity_rows=13
# Exported 38 shots for Player 18 → skeleton_exports/skeleton_export_Player 18.csv
# [76/165] Player 18: weak_targets=0 | unity_rows=38
# Exported 39 shots for Player 19 → skeleton_exports/skeleton_export_Player 19.csv
# [77/165] Player 19: weak_targets=2 | unity_rows=39
# Exported 33 shots for Player 2 → skeleton_exports/skeleton_export_Player 2.csv
# [78/165] Player 2: weak_targets=2 | unity_rows=33
# Exported 67 shots for Player 20 → skeleton_exports/skeleton_export_Player 20.csv
# [79/165] Player 20: weak_targets=1 | unity_rows=67
# Exported 13 shots for Player 21 → skeleton_exports/skeleton_export_Player 21.csv
# [80/165] Player 21: weak_targets=4 | unity_rows=13
# Exported 39 shots for Player 22 → skeleton_exports/skeleton_export_Player 22.csv
# [81/165] Player 22: weak_targets=1 | unity_rows=39
# Exported 132 shots for Player 23 → skeleton_exports/skeleton_export_Player 23.csv
# [82/165] Player 23: weak_targets=1 | unity_rows=132
# Exported 38 shots for Player 24 → skeleton_exports/skeleton_export_Player 24.csv
# [83/165] Player 24: weak_targets=0 | unity_rows=38
# Exported 36 shots for Player 25 → skeleton_exports/skeleton_export_Player 25.csv
# [84/165] Player 25: weak_targets=0 | unity_rows=36
# Exported 67 shots for Player 26 → skeleton_exports/skeleton_export_Player 26.csv
# [85/165] Player 26: weak_targets=0 | unity_rows=67
# Exported 40 shots for Player 27 → skeleton_exports/skeleton_export_Player 27.csv
# [86/165] Player 27: weak_targets=1 | unity_rows=40
# Exported 10 shots for Player 28 → skeleton_exports/skeleton_export_Player 28.csv
# [87/165] Player 28: weak_targets=0 | unity_rows=10
# Exported 2 shots for Player 29 → skeleton_exports/skeleton_export_Player 29.csv
# [88/165] Player 29: weak_targets=0 | unity_rows=2
# Exported 41 shots for Player 3 → skeleton_exports/skeleton_export_Player 3.csv
# [89/165] Player 3: weak_targets=1 | unity_rows=41
# Exported 17 shots for Player 30 → skeleton_exports/skeleton_export_Player 30.csv
# [90/165] Player 30: weak_targets=0 | unity_rows=17
# Exported 10 shots for Player 31 → skeleton_exports/skeleton_export_Player 31.csv
# [91/165] Player 31: weak_targets=0 | unity_rows=10
# Exported 40 shots for Player 32 → skeleton_exports/skeleton_export_Player 32.csv
# [92/165] Player 32: weak_targets=1 | unity_rows=40
# Exported 11 shots for Player 33 → skeleton_exports/skeleton_export_Player 33.csv
# [93/165] Player 33: weak_targets=0 | unity_rows=11
# Exported 60 shots for Player 34 → skeleton_exports/skeleton_export_Player 34.csv
# [94/165] Player 34: weak_targets=2 | unity_rows=60
# Exported 49 shots for Player 35 → skeleton_exports/skeleton_export_Player 35.csv
# [95/165] Player 35: weak_targets=2 | unity_rows=49
# Exported 16 shots for Player 36 → skeleton_exports/skeleton_export_Player 36.csv
# [96/165] Player 36: weak_targets=2 | unity_rows=16
# Exported 60 shots for Player 37 → skeleton_exports/skeleton_export_Player 37.csv
# [97/165] Player 37: weak_targets=2 | unity_rows=60
# Exported 38 shots for Player 38 → skeleton_exports/skeleton_export_Player 38.csv
# [98/165] Player 38: weak_targets=3 | unity_rows=38
# Exported 40 shots for Player 39 → skeleton_exports/skeleton_export_Player 39.csv
# [99/165] Player 39: weak_targets=2 | unity_rows=40
# Exported 5 shots for Player 4 → skeleton_exports/skeleton_export_Player 4.csv
# [100/165] Player 4: weak_targets=0 | unity_rows=5
# Exported 32 shots for Player 40 → skeleton_exports/skeleton_export_Player 40.csv
# [101/165] Player 40: weak_targets=1 | unity_rows=32
# Exported 6 shots for Player 41 → skeleton_exports/skeleton_export_Player 41.csv
# [102/165] Player 41: weak_targets=0 | unity_rows=6
# Exported 20 shots for Player 42 → skeleton_exports/skeleton_export_Player 42.csv
# [103/165] Player 42: weak_targets=1 | unity_rows=20
# Exported 40 shots for Player 43 → skeleton_exports/skeleton_export_Player 43.csv
# [104/165] Player 43: weak_targets=2 | unity_rows=40
# Exported 31 shots for Player 44 → skeleton_exports/skeleton_export_Player 44.csv
# [105/165] Player 44: weak_targets=0 | unity_rows=31
# Exported 59 shots for Player 45 → skeleton_exports/skeleton_export_Player 45.csv
# [106/165] Player 45: weak_targets=2 | unity_rows=59
# Exported 43 shots for Player 46 → skeleton_exports/skeleton_export_Player 46.csv
# [107/165] Player 46: weak_targets=1 | unity_rows=43
# Exported 37 shots for Player 47 → skeleton_exports/skeleton_export_Player 47.csv
# [108/165] Player 47: weak_targets=1 | unity_rows=37
# Exported 58 shots for Player 48 → skeleton_exports/skeleton_export_Player 48.csv
# [109/165] Player 48: weak_targets=2 | unity_rows=58
# Exported 80 shots for Player 49 → skeleton_exports/skeleton_export_Player 49.csv
# [110/165] Player 49: weak_targets=1 | unity_rows=80
# Exported 37 shots for Player 5 → skeleton_exports/skeleton_export_Player 5.csv
# [111/165] Player 5: weak_targets=0 | unity_rows=37
# Exported 34 shots for Player 50 → skeleton_exports/skeleton_export_Player 50.csv
# [112/165] Player 50: weak_targets=1 | unity_rows=34
# Exported 62 shots for Player 51 → skeleton_exports/skeleton_export_Player 51.csv
# [113/165] Player 51: weak_targets=0 | unity_rows=62
# Exported 90 shots for Player 52 → skeleton_exports/skeleton_export_Player 52.csv
# [114/165] Player 52: weak_targets=1 | unity_rows=90
# Exported 50 shots for Player 53 → skeleton_exports/skeleton_export_Player 53.csv
# [115/165] Player 53: weak_targets=0 | unity_rows=50
# Exported 61 shots for Player 54 → skeleton_exports/skeleton_export_Player 54.csv
# [116/165] Player 54: weak_targets=1 | unity_rows=61
# Exported 43 shots for Player 55 → skeleton_exports/skeleton_export_Player 55.csv
# [117/165] Player 55: weak_targets=1 | unity_rows=43
# Exported 5 shots for Player 56 → skeleton_exports/skeleton_export_Player 56.csv
# [118/165] Player 56: weak_targets=0 | unity_rows=5
# Exported 8 shots for Player 57 → skeleton_exports/skeleton_export_Player 57.csv
# [119/165] Player 57: weak_targets=0 | unity_rows=8
# Exported 70 shots for Player 58 → skeleton_exports/skeleton_export_Player 58.csv
# [120/165] Player 58: weak_targets=3 | unity_rows=70
# Exported 791 shots for Player 59 → skeleton_exports/skeleton_export_Player 59.csv
# [121/165] Player 59: weak_targets=0 | unity_rows=791
# Exported 41 shots for Player 6 → skeleton_exports/skeleton_export_Player 6.csv
# [122/165] Player 6: weak_targets=2 | unity_rows=41
# Exported 28 shots for Player 60 → skeleton_exports/skeleton_export_Player 60.csv
# [123/165] Player 60: weak_targets=2 | unity_rows=28
# Exported 113 shots for Player 61 → skeleton_exports/skeleton_export_Player 61.csv
# [124/165] Player 61: weak_targets=0 | unity_rows=113
# Exported 3 shots for Player 62 → skeleton_exports/skeleton_export_Player 62.csv
# [125/165] Player 62: weak_targets=0 | unity_rows=3
# Exported 62 shots for Player 63 → skeleton_exports/skeleton_export_Player 63.csv
# [126/165] Player 63: weak_targets=1 | unity_rows=62
# Exported 325 shots for Player 64 → skeleton_exports/skeleton_export_Player 64.csv
# [127/165] Player 64: weak_targets=0 | unity_rows=325
# Exported 125 shots for Player 65 → skeleton_exports/skeleton_export_Player 65.csv
# [128/165] Player 65: weak_targets=1 | unity_rows=125
# Exported 38 shots for Player 66 → skeleton_exports/skeleton_export_Player 66.csv
# [129/165] Player 66: weak_targets=1 | unity_rows=38
# Exported 37 shots for Player 67 → skeleton_exports/skeleton_export_Player 67.csv
# [130/165] Player 67: weak_targets=1 | unity_rows=37
# Exported 58 shots for Player 68 → skeleton_exports/skeleton_export_Player 68.csv
# [131/165] Player 68: weak_targets=2 | unity_rows=58
# Exported 59 shots for Player 69 → skeleton_exports/skeleton_export_Player 69.csv
# [132/165] Player 69: weak_targets=1 | unity_rows=59
# Exported 0 shots for Player 7 → skeleton_exports/skeleton_export_Player 7.csv
# [133/165] Player 7: weak_targets=0 | unity_rows=0
# Exported 22 shots for Player 70 → skeleton_exports/skeleton_export_Player 70.csv
# [134/165] Player 70: weak_targets=2 | unity_rows=22
# Exported 0 shots for Player 71 → skeleton_exports/skeleton_export_Player 71.csv
# [135/165] Player 71: weak_targets=0 | unity_rows=0
# Exported 21 shots for Player 72 → skeleton_exports/skeleton_export_Player 72.csv
# [136/165] Player 72: weak_targets=1 | unity_rows=21
# Exported 60 shots for Player 73 → skeleton_exports/skeleton_export_Player 73.csv
# [137/165] Player 73: weak_targets=1 | unity_rows=60
# Exported 29 shots for Player 74 → skeleton_exports/skeleton_export_Player 74.csv
# [138/165] Player 74: weak_targets=2 | unity_rows=29
# Exported 38 shots for Player 75 → skeleton_exports/skeleton_export_Player 75.csv
# [139/165] Player 75: weak_targets=2 | unity_rows=38
# Exported 62 shots for Player 76 → skeleton_exports/skeleton_export_Player 76.csv
# [140/165] Player 76: weak_targets=0 | unity_rows=62
# Exported 36 shots for Player 77 → skeleton_exports/skeleton_export_Player 77.csv
# [141/165] Player 77: weak_targets=0 | unity_rows=36
# Exported 0 shots for Player 78 → skeleton_exports/skeleton_export_Player 78.csv
# [142/165] Player 78: weak_targets=0 | unity_rows=0
# Exported 73 shots for Player 79 → skeleton_exports/skeleton_export_Player 79.csv
# [143/165] Player 79: weak_targets=0 | unity_rows=73
# Exported 61 shots for Player 8 → skeleton_exports/skeleton_export_Player 8.csv
# [144/165] Player 8: weak_targets=2 | unity_rows=61
# Exported 9 shots for Player 80 → skeleton_exports/skeleton_export_Player 80.csv
# [145/165] Player 80: weak_targets=0 | unity_rows=9
# Exported 39 shots for Player 81 → skeleton_exports/skeleton_export_Player 81.csv
# [146/165] Player 81: weak_targets=2 | unity_rows=39
# Exported 45 shots for Player 82 → skeleton_exports/skeleton_export_Player 82.csv
# [147/165] Player 82: weak_targets=1 | unity_rows=45
# Exported 45 shots for Player 83 → skeleton_exports/skeleton_export_Player 83.csv
# [148/165] Player 83: weak_targets=2 | unity_rows=45
# Exported 61 shots for Player 84 → skeleton_exports/skeleton_export_Player 84.csv
# [149/165] Player 84: weak_targets=2 | unity_rows=61
# Exported 33 shots for Player 85 → skeleton_exports/skeleton_export_Player 85.csv
# [150/165] Player 85: weak_targets=2 | unity_rows=33
# Exported 46 shots for Player 86 → skeleton_exports/skeleton_export_Player 86.csv
# [151/165] Player 86: weak_targets=2 | unity_rows=46
# Exported 32 shots for Player 87 → skeleton_exports/skeleton_export_Player 87.csv
# [152/165] Player 87: weak_targets=1 | unity_rows=32
# Exported 38 shots for Player 88 → skeleton_exports/skeleton_export_Player 88.csv
# [153/165] Player 88: weak_targets=2 | unity_rows=38
# Exported 33 shots for Player 89 → skeleton_exports/skeleton_export_Player 89.csv
# [154/165] Player 89: weak_targets=2 | unity_rows=33
# Exported 8 shots for Player 9 → skeleton_exports/skeleton_export_Player 9.csv
# [155/165] Player 9: weak_targets=0 | unity_rows=8
# Exported 41 shots for Player 90 → skeleton_exports/skeleton_export_Player 90.csv
# [156/165] Player 90: weak_targets=1 | unity_rows=41
# Exported 37 shots for Player 91 → skeleton_exports/skeleton_export_Player 91.csv
# [157/165] Player 91: weak_targets=0 | unity_rows=37
# Exported 37 shots for Player 92 → skeleton_exports/skeleton_export_Player 92.csv
# [158/165] Player 92: weak_targets=3 | unity_rows=37
# Exported 56 shots for Player 93 → skeleton_exports/skeleton_export_Player 93.csv
# [159/165] Player 93: weak_targets=3 | unity_rows=56
# Exported 31 shots for Player 94 → skeleton_exports/skeleton_export_Player 94.csv
# [160/165] Player 94: weak_targets=3 | unity_rows=31
# Exported 18 shots for Player 95 → skeleton_exports/skeleton_export_Player 95.csv
# [161/165] Player 95: weak_targets=1 | unity_rows=18
# Exported 17 shots for Player 96 → skeleton_exports/skeleton_export_Player 96.csv
# [162/165] Player 96: weak_targets=2 | unity_rows=17
# Exported 59 shots for Player 97 → skeleton_exports/skeleton_export_Player 97.csv
# [163/165] Player 97: weak_targets=2 | unity_rows=59
# Exported 397 shots for Player 98 → skeleton_exports/skeleton_export_Player 98.csv
# [164/165] Player 98: weak_targets=0 | unity_rows=397
# Exported 60 shots for Player 99 → skeleton_exports/skeleton_export_Player 99.csv
# [165/165] Player 99: weak_targets=3 | unity_rows=60
# Batch completed for 165 players.

# %% [markdown]
# ## 12. Summary
#
# ### Pipeline overview
#
# Three-stage causal chain: **Biomechanics → Ball Flight → Miss Distance.**
#
# | Stage | Model | CV R² | Role |
# |---|---|---|---|
# | Stage 1 | LightGBM (GroupKFold) | 0.53–0.88 | Biomech → ball flight; drives per-shot SHAP |
# | Stage 2 | Random Forest per shot context | 0.85–0.98 (median 0.94) | Ball flight → miss distance; validates the chain |
# | Stage 3 | LightGBM (GroupKFold) | ≈ 0 | Direct biomech → miss distance; confirms device limitation |
#
# ### Stage 1 findings
#
# Held-out CV R² on jump shots (GroupKFold, Player 163 capped at 500 shots):
# - `Initial.Ball.Velocity` ≈ 0.88
# - `Release.Height.Norm` ≈ 0.68
# - `Max.Ball.Arc` ≈ 0.57
# - `Initial.Ball.Angle` ≈ 0.53
#
# Two original targets (`Ball_to_Rim_Angle`, `Ball_Velocity`) failed the CV gate and were dropped.
#
# ### Stage 2 findings
#
# R² 0.85–0.98 (median 0.94) across all 20 `(Shot.Location × Shot.Type)` groups. Once a shot leaves the hand with measurable initial conditions, miss distance is highly predictable. This is the strongest layer of the chain and validates that improving Stage 1 targets meaningfully reduces miss distance.
#
# ### Stage 3 findings
#
# R²_cv ≈ 0 for jump shots **and** free throws. Free throws being equally bad is the key evidence: the marker-based device is categorically missing the discriminating signal (likely wrist snap timing, finger roll-off, ball spin at release). This is a device limitation, not a pipeline flaw — the per-shot recommendations route around it via the Stage 1 → Stage 2 indirect chain.
#
# ### Player 163 case study
#
# 25,868 total shots; Player 163 = 2,873 jump shots (13% of dataset). No ball-flight priority targets — his median ball flight sits in the made-shot optimal band on all four metrics. Make/miss self-comparison shows moderate but consistent differences in torso flexion, ankle dorsiflexion, and torso velocity (top effect size 0.27). High shot-to-shot variability on shoulder extension and ankle dorsiflexion relative to 69 height-matched peers (97–99th percentile).
#
#
#
# ### What the Unity team gets
#
# `unity_exports/unity_export_JumpShots_<PlayerID>.csv` — one row per shot:
#
# | Column group | What it contains |
# |---|---|
# | `orig_<joint>` | Actual measured joint angle (Flexion, Extension, Alignment, ROM, Velocity per phase) |
# | `rec_<joint>` | Recommended value: capped at realistic ranges or player makes-median for the top 3–5 targeted features |
# | `orig_pred_<target>` | Stage 1 model prediction for that shot's ball flight |
# | `rec_pred_<target>` | Re-prediction after applying the biomechanical changes |
# | metadata | `ShotId`, `Made`, `Shot.Type`, `Top_Feats` changed, `Max_Impact_Target` |
#
# #### Addressing Context vs Biomechanics (Key Finding)
# A massive breakthrough during testing was recognizing the overlap between **context** (e.g., `Shot.Distance`, `Shot.Type`, `Days`) and **biomechanical execution**.
# 1. **The Model Layer:** Models must be fully aware of the context. We feed `Shot.Distance` into the TreeExplainer so LightGBM recognizes that deep threes naturally miss more than midrange jumpers.
# 2. **The Extraction Layer:** A coaching system cannot output "You missed because you were 25 feet away. Move closer." When sorting SHAP impacts for the final export CSV, the post-processor strictly removes uncoachable environmental columns `[Distance, Type, Year, Days, etc.]`. Only biological variations (e.g. `BallVeloRelease` or `ShoulderFlexion`) are pushed to the viewer.
#
# Feature selection is per-shot and SHAP-driven. Alignment columns use pre-unwrapped values for shortest-arc interpolation in Unity (`Mathf.DeltaAngle` / `Quaternion.Slerp`); all other columns use linear interpolation. Max angular delta bounds (e.g., ±12°) explicitly prevent "broken bone" animations in the software engine.

# %%
# Test: Print realistic biomechanic changes for 4 shots of Player 163
test_player = "Player 163"

# Call the unity export generator directly
test_df = build_unity_export(
    test_player, df,
    models=models,
    explainers_dict=explainers_dict,
    X_per_target=X_per_target,
    y_per_target=y_per_target,
    shot_group=SHOT_GROUP
)

if not test_df.empty:
    print(f"=== TESTING UNITY EXPORT FOR {test_player} ===\n")
    # Take 4 sample shots
    sample_shots = test_df.head(4)
    
    for _, row in sample_shots.iterrows():
        print(f"--- Shot {row['ShotId']} | {row['Shot.Type']} | {len(row['Top_Feats'].split(', '))} features ---")
        print(f"{'feature':<36} {'orig':>8} {'rec':>8} {'delta':>8}")
        
        feats = row['Top_Feats'].split(', ')
        for feat in feats:
            if not feat.strip(): continue
            orig_col = f"orig_{feat}"
            rec_col = f"rec_{feat}"
            
            if orig_col in row and rec_col in row:
                ov = row[orig_col]
                rv = row[rec_col]
                delta = rv - ov
                print(f"{feat:<36} {ov:>8.2f} {rv:>8.2f} {delta:>8.2f}")
        print("\n")
else:
    print(f"Could not generate export for {test_player}.")
# Out:
# === TESTING UNITY EXPORT FOR Player 163 ===
#
# --- Shot 22629 | Off the Dribble | 5 features ---
# feature                                  orig      rec    delta
# BallVeloRelease                          4.86     5.59     0.73
# TorsoVeloPostHitch                      -0.25     0.25     0.50
# maxKneeFlexionDominantPreHitch         -36.15   -48.15   -12.00
# maxShoulderExtensionDominantPostHitch    56.86    68.86    12.00
# BallVeloRelease__zwithin                -1.27    -0.77     0.50
#
#
# --- Shot 22630 | Off the Dribble | 5 features ---
# feature                                  orig      rec    delta
# BallVeloRelease                          5.16     5.59     0.43
# ElbowFlexionAtT0Dominant                60.47    72.47    12.00
# TorsoVeloPostHitch                      -0.00     0.50     0.50
# ShoulderAlignmentRelease__zwithin       -1.70    -1.36     0.34
# maxHipFlexionDominantPostHitch          60.01    48.01   -12.00
#
#
# --- Shot 22631 | Off the Dribble | 5 features ---
# feature                                  orig      rec    delta
# BallVeloRelease                          3.89     4.66     0.78
# ElbowFlexionAtT0Dominant                60.82    72.82    12.00
# BallVeloRelease__zwithin                -2.69    -2.15     0.54
# TorsoVeloRelease                         1.93     1.43    -0.50
# maxShoulderFlexionNonDominantPreHitch     9.70    21.70    12.00
#
#
# --- Shot 22632 | Off the Dribble | 5 features ---
# feature                                  orig      rec    delta
# BallVeloRelease                          4.13     4.96     0.83
# TorsoVeloRelease                         1.98     1.48    -0.50
# ElbowFlexionAtT0Dominant                66.60    78.60    12.00
# MaxStanceGapHitch                        0.15     0.18     0.03
# TorsoVeloRelease__zwithin                3.48     2.78    -0.70
